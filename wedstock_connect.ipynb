# %%
# Thư viện WebSocket để kết nối real-time với Bitget API
import websocket

# Thư viện xử lý JSON (dữ liệu từ API Bitget ở định dạng JSON)
import json

# Thư viện ghi file CSV để lưu dữ liệu ticker và candlestick
import csv

# Thư viện xử lý thời gian (timestamp, datetime conversion)
import datetime

# Thư viện xử lý file và thư mục (kiểm tra file tồn tại, kích thước file)
import os

# Thư viện pandas để xử lý dữ liệu dạng bảng (chưa sử dụng trong code này)
import pandas as pd

# Thư viện threading để chạy nhiều tác vụ cùng lúc (WebSocket chạy trong background)
import threading

# Thư viện time để tạm dừng chương trình và điều khiển thời gian chạy
import time

# Thư viện SQLAlchemy để kết nối database (đã import nhưng chưa sử dụng)
from sqlalchemy import create_engine

# Thư viện xử lý URL encoding (chưa sử dụng trong code này)
import urllib.parse

# %%
# ==================== CẤU HÌNH KẾT NỐI VÀ DỮ LIỆU ====================

# URL WebSocket public của Bitget để nhận dữ liệu real-time
WEBSOCKET_URL = "wss://ws.bitget.com/v2/ws/public"

# Danh sách các cặp cryptocurrency cần theo dõi (SOL, BTC, ETH với USDT)
INSTRUMENT_IDS = ["SOLUSDT", "BTCUSDT", "ETHUSDT"]  

# Tên file CSV để lưu dữ liệu ticker (giá hiện tại, volume, thay đổi 24h)
CSV_FILE_NAME = "data.csv"

# %% [markdown]
# # TRY CẬP VÀO products ĐỂ LẤY DANH SÁCH COIN

# %%
import requests

def get_valid_trading_pairs():
    """Lấy danh sách trading pairs USDT hợp lệ từ Bitget API"""
    try:
        # Sử dụng API v2 để lấy symbols chính xác cho WebSocket
        url = "https://api.bitget.com/api/v2/spot/public/symbols"
        response = requests.get(url, timeout=10)
        
        if response.status_code == 200:
            data = response.json()
            
            if data.get('code') == '00000' and 'data' in data:
                # Lọc chỉ các USDT pairs đang hoạt động
                valid_pairs = [
                    item.get('symbol') 
                    for item in data['data'] 
                    if (item.get('status') == 'online' and 
                        item.get('symbol', '').endswith('USDT'))
                ]
                
                print(f"✅ Lấy được {len(valid_pairs)} USDT trading pairs")
                return valid_pairs
            else:
                print(f"❌ API Error: {data.get('msg', 'Unknown error')}")
                return get_fallback_pairs()
        else:
            print(f"❌ HTTP Error: {response.status_code}")
            return get_fallback_pairs()
            
    except requests.exceptions.RequestException as e:
        print(f"❌ Network Error: {e}")
        return get_fallback_pairs()
    except Exception as e:
        print(f"❌ Unexpected Error: {e}")
        return get_fallback_pairs()

def get_fallback_pairs():
    """Trả về danh sách trading pairs dự phòng khi API thất bại"""
    fallback_pairs = ["BTCUSDT", "ETHUSDT", "SOLUSDT", "BNBUSDT", "XRPUSDT"]
    print(f"🔄 Sử dụng {len(fallback_pairs)} trading pairs dự phòng")
    return fallback_pairs

def filter_top_pairs(pairs, limit=10):
    """Lọc top N trading pairs và loại bỏ các pairs có thể có vấn đề"""
    # Loại bỏ các pairs có tên lạ hoặc không phổ biến
    excluded_keywords = ['TEST', 'MOCK', 'DEMO', 'TEMP', '_SPBL']
    
    filtered_pairs = [
        pair for pair in pairs 
        if not any(keyword in pair.upper() for keyword in excluded_keywords)
    ]
    
    # Ưu tiên các pairs phổ biến lên đầu
    popular_pairs = ["BTCUSDT", "ETHUSDT", "SOLUSDT", "BNBUSDT", "XRPUSDT", 
                    "ADAUSDT", "DOTUSDT", "LINKUSDT", "UNIUSDT", "LTCUSDT"]
    priority_pairs = [pair for pair in popular_pairs if pair in filtered_pairs]
    other_pairs = [pair for pair in filtered_pairs if pair not in popular_pairs]
    
    # Kết hợp và lấy top N
    final_pairs = (priority_pairs + other_pairs)[:limit]
    
    return final_pairs

# ===== MAIN EXECUTION =====
print("🔍 Đang lấy danh sách trading pairs...")

# Lấy trading pairs từ API
all_trading_pairs = get_valid_trading_pairs()

# Lọc và lấy top 10 pairs an toàn
INSTRUMENT_IDS = filter_top_pairs(all_trading_pairs, limit=10)

# Verify kết quả cuối cùng
if not INSTRUMENT_IDS:
    print("⚠️ Không có trading pairs hợp lệ, sử dụng mặc định")
    INSTRUMENT_IDS = ["BTCUSDT", "ETHUSDT", "SOLUSDT"]

print(f"🎯 Trading pairs được chọn: {INSTRUMENT_IDS}")
print(f"📊 Tổng số pairs: {len(INSTRUMENT_IDS)}")
# Out:
# 792

# %% [markdown]
# # CẤU HÌNH HOÀN CHỈNH CHO TICKER + CANDLESTICK

# %%
# URL WebSocket public của Bitget để nhận dữ liệu real-time
WEBSOCKET_URL = "wss://ws.bitget.com/v2/ws/public"

# Danh sách các cặp cryptocurrency cần theo dõi (đã được lọc)
# INSTRUMENT_IDS đã được set ở cell trước

# Tạo DataFrame để lưu dữ liệu ticker
ticker_df = pd.DataFrame(columns=[
    "thoi_gian", "timestamp_api", "instId", "lastPr", "bidPr", "askPr",
    "bidSz", "askSz", "open24h", "high24h", "low24h", "change24h",
    "baseVolume", "quoteVolume", "openUtc", "changeUtc24h", "action"
])

# Tạo DataFrame để lưu dữ liệu candlestick
candlestick_df = pd.DataFrame(columns=[
    "thoi_gian_he_thong", "start_time", "open_price", "high_price", 
    "low_price", "close_price", "volume_base", "volume_quote", 
    "volume_usdt", "instId", "timeframe", "action"
])

# Các khung thời gian candlestick cần theo dõi
TIMEFRAMES = ["candle1m", "candle5m", "candle15m", "candle1H"]

print("✅ DataFrames đã được khởi tạo")
print(f"📈 Ticker DataFrame: {len(ticker_df)} rows")
print(f"🕯️ Candlestick DataFrame: {len(candlestick_df)} rows")

# %% [markdown]
# # HÀM TẠO FILE CSV CHO DỮ LIỆU TICKER

# %%
def tao_file_csv():
    """Tạo file CSV với header chuẩn cho dữ liệu ticker"""
    
    # Định nghĩa các cột dữ liệu cho ticker (giá, volume, thống kê 24h)
    header = [
    "thoi_gian" ,          # Thời gian hệ thống ghi nhận dữ liệu (local time)
    "timestamp_api",       # Timestamp từ API Bitget (ms)
    "instId",              # Mã sản phẩm (ví dụ: ETHUSDT, BTCUSDT)
    "lastPr",              # Giá giao dịch gần nhất (current price)
    "bidPr",               # Giá mua cao nhất (highest bid)
    "askPr",               # Giá bán thấp nhất (lowest ask)
    "bidSz",               # Khối lượng đặt mua tại giá bid
    "askSz",               # Khối lượng đặt bán tại giá ask
    "open24h",             # Giá mở cửa 24 giờ trước
    "high24h",             # Giá cao nhất trong 24h
    "low24h",              # Giá thấp nhất trong 24h
    "change24h",           # Phần trăm thay đổi trong 24h
    "baseVolume",          # Khối lượng giao dịch theo base currency (coin)
    "quoteVolume",         # Khối lượng giao dịch theo quote currency (USDT)
    "openUtc",             # Giá mở cửa tại UTC+0
    "changeUtc24h",        # Thay đổi giá tại UTC+0 trong 24h
    "action"               # Loại dữ liệu: snapshot (cũ) hoặc update (mới)
]

    # Kiểm tra file có tồn tại và có dữ liệu chưa
    if not os.path.exists(CSV_FILE_NAME) or os.path.getsize(CSV_FILE_NAME) == 0:
        # Tạo file mới với header nếu chưa tồn tại
        with open(CSV_FILE_NAME, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(header)
        print(f"Đã tạo file CSV với {len(header)} cột: {CSV_FILE_NAME}")
    else:
        print(f"File CSV đã tồn tại: {CSV_FILE_NAME}")

# Gọi hàm tạo file ticker ngay khi chạy
tao_file_csv()
# Out:
# File CSV đã tồn tại: data.csv

# %% [markdown]
# # HÀM TẠO FILE CSV CHO DỮ LIỆU CANDLESTICK

# %%
def tao_file_candlestick_csv():
    """Tạo file CSV với header chuẩn cho dữ liệu candlestick (nến OHLC)"""
    
    # Định nghĩa các cột dữ liệu cho candlestick (nến OHLC + volume)
    candlestick_header = [
        "thoi_gian_he_thong",      # Thời gian hệ thống ghi nhận (local time)
    "start_time",              # Thời gian bắt đầu nến (từ API, đã convert sang readable)
    "open_price",              # Giá mở cửa của nến (Open)
    "high_price",              # Giá cao nhất của nến (High)
    "low_price",               # Giá thấp nhất của nến (Low)
    "close_price",             # Giá đóng cửa của nến (Close)
    "volume_base",             # Khối lượng giao dịch theo base currency
    "volume_quote",            # Khối lượng giao dịch theo quote currency
    "volume_usdt",             # Khối lượng giao dịch tính bằng USDT
    "instId",                  # Mã sản phẩm (ETHUSDT, BTCUSDT, SOLUSDT)
    "timeframe",               # Khung thời gian nến (1m, 5m, 15m, 1H)
    "action"                   # Loại dữ liệu: snapshot hoặc update
]
    
    # Kiểm tra file candlestick có tồn tại chưa
    if not os.path.exists(CANDLESTICK_CSV_FILE) or os.path.getsize(CANDLESTICK_CSV_FILE) == 0:
        # Tạo file mới với header nếu chưa tồn tại
        with open(CANDLESTICK_CSV_FILE, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(candlestick_header)
        print(f"Đã tạo file Candlestick CSV với {len(candlestick_header)} cột: {CANDLESTICK_CSV_FILE}")
    else:
        print(f"File Candlestick CSV đã tồn tại: {CANDLESTICK_CSV_FILE}")

# Gọi hàm tạo file candlestick ngay khi chạy
tao_file_candlestick_csv()
# Out:
# File Candlestick CSV đã tồn tại: candlestick_data.csv

# %% [markdown]
# # BIẾN TOÀN CỤC VÀ HÀM XỬ LÝ WEBSOCKET

# %%
# Mảng lưu trữ toàn bộ dữ liệu ticker và candlestick để debug
all_ticker_data = []
all_candlestick_data = []

def on_open_enhanced(ws):
    """Hàm được gọi khi WebSocket kết nối thành công"""
    print("🔗 Đã kết nối thành công với Bitget WebSocket")
    
    # === ĐĂNG KÝ THEO DÕI TICKER CHO TẤT CẢ SYMBOLS ===
    for inst_id in INSTRUMENT_IDS:
        ticker_message = {
            "op": "subscribe",        
            "args": [
                {    
                    "instType": "SPOT",      
                    "channel": "ticker",     
                    "instId": inst_id        
                }
            ]
        }
        ws.send(json.dumps(ticker_message))
        print(f"📊 Đăng ký ticker: {inst_id}")
    
    # === ĐĂNG KÝ THEO DÕI CANDLESTICK CHO TẤT CẢ SYMBOLS VÀ TIMEFRAMES ===
    for inst_id in INSTRUMENT_IDS:
        for timeframe in TIMEFRAMES:
            candlestick_message = {
                "op": "subscribe",
                "args": [
                    {    
                        "instType": "SPOT",      
                        "channel": timeframe,    
                        "instId": inst_id        
                    }
                ]
            }
            ws.send(json.dumps(candlestick_message))
            print(f"🕯️ Đăng ký candlestick: {inst_id} - {timeframe}")
    
    print(f"✅ Hoàn tất subscribe cho {len(INSTRUMENT_IDS)} coins với {len(TIMEFRAMES)} timeframes")

def on_message_enhanced(ws, message_str):
    """Hàm xử lý tin nhắn từ WebSocket - route dữ liệu đến đúng processor"""
    global all_ticker_data, all_candlestick_data
    
    # Parse JSON từ message
    data = json.loads(message_str)
    
    # Kiểm tra message type
    if "event" in data:
        if data["event"] == "error":
            print(f"❌ WebSocket Error: {data.get('msg', 'Unknown error')}")
            return
        elif data["event"] == "subscribe":
            print(f"✅ Subscribed: {data.get('arg', {}).get('instId', 'Unknown')} - {data.get('arg', {}).get('channel', 'Unknown')}")
            return
    
    # Kiểm tra loại channel để route dữ liệu đúng chỗ
    if "arg" in data and "channel" in data["arg"]:
        channel = data["arg"]["channel"]
        
        if channel == "ticker":
            # Dữ liệu ticker: giá hiện tại, volume, bid/ask
            all_ticker_data.append(data)
            process_ticker_data(data)
            
        elif channel.startswith("candle"):
            # Dữ liệu candlestick: nến OHLC với các timeframe khác nhau
            all_candlestick_data.append(data)
            process_candlestick_data(data)

def process_ticker_data(data):
    """Xử lý và lưu dữ liệu ticker vào DataFrame"""
    global ticker_df
    
    if "data" in data and data["data"]:
        ticker = data["data"][0]  
        
        # === TRÍCH XUẤT DỮ LIỆU TICKER ===
        new_row = {
            "thoi_gian": datetime.datetime.now().isoformat(),
            "timestamp_api": ticker.get('ts'),
            "instId": ticker.get('instId'),
            "lastPr": ticker.get('lastPr'),
            "bidPr": ticker.get('bidPr'),
            "askPr": ticker.get('askPr'),
            "bidSz": ticker.get('bidSz'),
            "askSz": ticker.get('askSz'),
            "open24h": ticker.get('open24h'),
            "high24h": ticker.get('high24h'),
            "low24h": ticker.get('low24h'),
            "change24h": ticker.get('change24h'),
            "baseVolume": ticker.get('baseVolume'),
            "quoteVolume": ticker.get('quoteVolume'),
            "openUtc": ticker.get('openUtc'),
            "changeUtc24h": ticker.get('changeUtc24h'),
            "action": data.get('action', 'unknown')
        }
        
        # === THÊM DỮ LIỆU VÀO DATAFRAME ===
        ticker_df = pd.concat([ticker_df, pd.DataFrame([new_row])], ignore_index=True)
        
        # === HIỂN THỊ THÔNG TIN TICKER TRÊN CONSOLE ===
        print(f"📈 TICKER {new_row['instId']} | Giá: {new_row['lastPr']} | Thay đổi 24h: {new_row['change24h']} | Total: {len(ticker_df)}")

def process_candlestick_data(data):
    """Xử lý và lưu dữ liệu candlestick (nến OHLC) vào DataFrame"""
    global candlestick_df
    
    if "data" in data and data["data"]:
        candle = data["data"][0]  
        arg = data.get("arg", {})
        
        # === CONVERT TIMESTAMP SANG ĐỊNH DẠNG DỄ ĐỌC ===
        try:
            start_time_readable = datetime.datetime.fromtimestamp(int(candle[0])/1000).isoformat()
        except:
            start_time_readable = candle[0]
        
        # === TRÍCH XUẤT DỮ LIỆU TỪ CANDLE ARRAY ===
        new_row = {
            "thoi_gian_he_thong": datetime.datetime.now().isoformat(),
            "start_time": start_time_readable,
            "open_price": candle[1],
            "high_price": candle[2],
            "low_price": candle[3],
            "close_price": candle[4],
            "volume_base": candle[5],
            "volume_quote": candle[6],
            "volume_usdt": candle[7],
            "instId": arg.get('instId'),
            "timeframe": arg.get('channel'),
            "action": data.get('action', 'unknown')
        }
        
        # === THÊM DỮ LIỆU VÀO DATAFRAME ===
        candlestick_df = pd.concat([candlestick_df, pd.DataFrame([new_row])], ignore_index=True)
        
        # === HIỂN THỊ THÔNG TIN CANDLESTICK TRÊN CONSOLE ===
        print(f"🕯️ CANDLE {new_row['instId']} {new_row['timeframe']} | O:{new_row['open_price']} H:{new_row['high_price']} L:{new_row['low_price']} C:{new_row['close_price']} | Total: {len(candlestick_df)}")

def on_error(ws, error):
    """Hàm xử lý lỗi WebSocket"""
    print(f"❌ WebSocket Error: {error}")

def on_close(ws, close_status_code, close_msg):
    """Hàm xử lý khi WebSocket đóng kết nối"""
    print(f"🔌 Kết nối WebSocket đã đóng")

# %% [markdown]
# # CHẠY WEBSOCKET VÀ ĐIỀU KHIỂN CHƯƠNG TRÌNH

# %%
# === CẤU HÌNH THỜI GIAN CHẠY ===
a = 60  # 1 phút = 60 giây
b = a * 60  # 1 giờ = 3600 giây
c = b * 24  # 1 ngày = 86400 giây

def run_ws_enhanced():
    """Hàm chạy WebSocket với ping để duy trì kết nối"""
    ws.run_forever(ping_interval=30, ping_timeout=10)

# === TẠO ĐỐI TƯỢNG WEBSOCKET VỚI CÁC CALLBACK FUNCTIONS ===
ws = websocket.WebSocketApp(WEBSOCKET_URL,
                          on_open=on_open_enhanced,      
                          on_message=on_message_enhanced,  
                          on_error=on_error,            
                          on_close=on_close)            

# === THÔNG BÁO BẮT ĐẦU CRAWLING ===
print("🚀 Bắt đầu kết nối đến Bitget WebSocket...")
print("💾 Dữ liệu sẽ được lưu vào DataFrames")
print("⏹️ Nhấn Ctrl+C để dừng")

# === CHẠY WEBSOCKET TRONG BACKGROUND THREAD ===
ws_thread = threading.Thread(target=run_ws_enhanced)
ws_thread.daemon = True  
ws_thread.start()

# === THIẾT LẬP THỜI GIAN CHẠY ===
run_duration = a # Chạy trong 1 phút (60 giây)

# === CHẠY CHƯƠNG TRÌNH VÀ XỬ LÝ KEYBOARD INTERRUPT ===
try:
    time.sleep(run_duration)  
except KeyboardInterrupt:
    print("\n⏹️ Đã dừng bằng Ctrl+C")  

# === ĐÓNG KẾT NỐI VÀ THỐNG KÊ ===
ws.close()
print(f"✅ Đã ngắt kết nối sau {run_duration} giây.")
print(f"📊 Ticker data: {len(all_ticker_data)} messages")        
print(f"🕯️ Candlestick data: {len(all_candlestick_data)} messages")
print(f"📈 Ticker DataFrame: {len(ticker_df)} rows")
print(f"🕯️ Candlestick DataFrame: {len(candlestick_df)} rows")
# Out:
# Bắt đầu kết nối đến Bitget (Ticker + Candlestick)...
# Ticker data sẽ được lưu vào: data.csv
# Candlestick data sẽ được lưu vào: candlestick_data.csv
# Nhấn Ctrl+C để dừng
# Đã kết nối thành công
# Đang theo dõi ticker LUMIAUSDT_SPBL
# Đang theo dõi ticker GOATUSDT_SPBL
# Đang theo dõi ticker ENAEUR_SPBL
# Đang theo dõi ticker TONCOINEUR_SPBL
# Đang theo dõi ticker SXRPSUSDT_SPBL
# Đang theo dõi ticker SHIBEUR_SPBL
# Đang theo dõi ticker WLDEUR_SPBL
# Đang theo dõi ticker DBRUSDT_SPBL
# Đang theo dõi ticker ACTUSDT_SPBL
# Đang theo dõi ticker GRASSUSDT_SPBL
# Đang theo dõi ticker NEIROCTOEUR_SPBL
# Đang theo dõi ticker SUIEUR_SPBL
# Đang theo dõi ticker TRXUSDT_SPBL
# Đang theo dõi ticker XNEWUSDT_SPBL
# Đang theo dõi ticker LINKUSDT_SPBL
# Đang theo dõi ticker ONDOEUR_SPBL
# Đang theo dõi ticker UNIUSDT_SPBL
# Đang theo dõi ticker SUSHIUSDT_SPBL
# Đang theo dõi ticker COMPUSDT_SPBL
# Đang theo dõi ticker SCREUR_SPBL
# Đang theo dõi ticker AAVEUSDT_SPBL
# Đang theo dõi ticker SCRUSDT_SPBL
# Đang theo dõi ticker YFIUSDT_SPBL
# Đang theo dõi ticker NEAREUR_SPBL
# Đang theo dõi ticker DOGEUSDT_SPBL
# Đang theo dõi ticker CHZUSDT_SPBL
# Đang theo dõi ticker PNUTUSDT_SPBL
# Đang theo dõi ticker SWELLUSDT_SPBL
# Đang theo dõi ticker WEETHETH_SPBL
# Đang theo dõi ticker LUCEUSDT_SPBL
# Đang theo dõi ticker FUSEUSDT_SPBL
# Đang theo dõi ticker BANUSDT_SPBL
# Đang theo dõi ticker NFPUSDT_SPBL
# Đang theo dõi ticker NSUSDT_SPBL
# Đang theo dõi ticker HIPPOUSDT_SPBL
# Đang theo dõi ticker PEPECOINUSDT_SPBL
# Đang theo dõi ticker FARTCOINUSDT_SPBL
# Đang theo dõi ticker PEAQUSDT_SPBL
# Đang theo dõi ticker MVUSDT_SPBL
# Đang theo dõi ticker BTCWUSD_SPBL
# Đang theo dõi ticker MOBILEUSDT_SPBL
# Đang theo dõi ticker SWCHUSDT_SPBL
# Đang theo dõi ticker $AIUSDT_SPBL
# Đang theo dõi ticker SOLUSDE_SPBL
# Đang theo dõi ticker SNEKUSDT_SPBL
# Đang theo dõi ticker RIFSOLUSDT_SPBL
# Đang theo dõi ticker OORTUSDT_SPBL
# Đang theo dõi ticker SOLOUSDT_SPBL
# Đang theo dõi ticker XAIUSDT_SPBL
# Đang theo dõi ticker FISUSDT_SPBL
# Đang theo dõi ticker ELAUSDT_SPBL
# Đang theo dõi ticker BONEUSDT_SPBL
# Đang theo dõi ticker RDNTUSDT_SPBL
# Đang theo dõi ticker SAROSUSDT_SPBL
# Đang theo dõi ticker MANTAUSDT_SPBL
# Đang theo dõi ticker PONKEUSDT_SPBL
# Đang theo dõi ticker PROPSUSDT_SPBL
# Đang theo dõi ticker UPCUSDT_SPBL
# Đang theo dõi ticker ORAIUSDT_SPBL
# Đang theo dõi ticker IOSTUSDT_SPBL
# Đang theo dõi ticker COREUSDT_SPBL
# Đang theo dõi ticker $ALTUSDT_SPBL
# Đang theo dõi ticker ONDOUSDT_SPBL
# Đang theo dõi ticker WIFUSDT_SPBL
# Đang theo dõi ticker AVAUSDT_SPBL
# Đang theo dõi ticker THENAUSDT_SPBL
# Đang theo dõi ticker CHESSUSDT_SPBL
# Đang theo dõi ticker ORNJUSDT_SPBL
# Đang theo dõi ticker JUPUSDT_SPBL
# Đang theo dõi ticker DMAILUSDT_SPBL
# Đang theo dõi ticker BLURUSDT_SPBL
# Đang theo dõi ticker API3USDT_SPBL
# Đang theo dõi ticker XAUTUSDT_SPBL
# Đang theo dõi ticker RAREUSDT_SPBL
# Đang theo dõi ticker TRUUSDT_SPBL
# Đang theo dõi ticker BIZAUSDT_SPBL
# Đang theo dõi ticker USDCEUR_SPBL
# Đang theo dõi ticker VRUSDT_SPBL
# Đang theo dõi ticker FIREUSDT_SPBL
# Đang theo dõi ticker CFXUSDT_SPBL
# Đang theo dõi ticker ZETAUSDT_SPBL
# Đang theo dõi ticker MDTUSDT_SPBL
# Đang theo dõi ticker COREUMUSDT_SPBL
# Đang theo dõi ticker VELOUSDT_SPBL
# Đang theo dõi ticker DYMUSDT_SPBL
# Đang theo dõi ticker MAVIAUSDT_SPBL
# Đang theo dõi ticker NAVXUSDT_SPBL
# Đang theo dõi ticker TRACUSDT_SPBL
# Đang theo dõi ticker LQTYUSDT_SPBL
# Đang theo dõi ticker STRKUSDT_SPBL
# Đang theo dõi ticker ASTOUSDT_SPBL
# Đang theo dõi ticker WLDUSDC_SPBL
# Đang theo dõi ticker HTXUSDT_SPBL
# Đang theo dõi ticker NEOUSDT_SPBL
# Đang theo dõi ticker FLMUSDT_SPBL
# Đang theo dõi ticker AZEROUSDT_SPBL
# Đang theo dõi ticker PIXELUSDT_SPBL
# Đang theo dõi ticker PRIME1USDT_SPBL
# Đang theo dõi ticker ELONUSDT_SPBL
# Đang theo dõi ticker VAIUSDT_SPBL
# Đang theo dõi ticker ASTRUSDT_SPBL
# Đang theo dõi ticker VELO1USDT_SPBL
# Đang theo dõi ticker STXUSDT_SPBL
# Đang theo dõi ticker FONUSDT_SPBL
# Đang theo dõi ticker TRXETH_SPBL
# Đang theo dõi ticker LTCETH_SPBL
# Đang theo dõi ticker GFALUSDT_SPBL
# Đang theo dõi ticker RJVUSDT_SPBL
# Đang theo dõi ticker RONUSDT_SPBL
# Đang theo dõi ticker XEMUSDT_SPBL
# Đang theo dõi ticker ZENUSDT_SPBL
# Đang theo dõi ticker LOOKSUSDT_SPBL
# Đang theo dõi ticker PEOPLEUSDT_SPBL
# Đang theo dõi ticker METISUSDT_SPBL
# Đang theo dõi ticker ACAUSDT_SPBL
# Đang theo dõi ticker ALPHAUSDT_SPBL
# Đang theo dõi ticker BABYDOGEUSDT_SPBL
# Đang theo dõi ticker JUVUSDT_SPBL
# Đang theo dõi ticker KLAYUSDT_SPBL
# Đang theo dõi ticker USDCUSDT_SPBL
# Đang theo dõi ticker AUDIOUSDT_SPBL
# Đang theo dõi ticker C98USDT_SPBL
# Đang theo dõi ticker TLOSUSDT_SPBL
# Đang theo dõi ticker ILVUSDT_SPBL
# Đang theo dõi ticker WEMIXUSDT_SPBL
# Đang theo dõi ticker RSS3USDT_SPBL
# Đang theo dõi ticker ARPAUSDT_SPBL
# Đang theo dõi ticker DUSKUSDT_SPBL
# Đang theo dõi ticker WOOUSDT_SPBL
# Đang theo dõi ticker FTTUSDT_SPBL
# Đang theo dõi ticker WINUSDT_SPBL
# Đang theo dõi ticker SUNUSDT_SPBL
# Đang theo dõi ticker PSTAKEUSDT_SPBL
# Đang theo dõi ticker ARUSDT_SPBL
# Đang theo dõi ticker PERPUSDT_SPBL
# Đang theo dõi ticker LUNAUSDT_SPBL
# Đang theo dõi ticker GMTUSDT_SPBL
# Đang theo dõi ticker SDUSDT_SPBL
# Đang theo dõi ticker MAGICUSDT_SPBL
# Đang theo dõi ticker KSMUSDT_SPBL
# Đang theo dõi ticker APEUSDT_SPBL
# Đang theo dõi ticker POKTUSDT_SPBL
# Đang theo dõi ticker XDCUSDT_SPBL
# Đang theo dõi ticker ADAUSDT_SPBL
# Đang theo dõi ticker EGLDUSDT_SPBL
# Đang theo dõi ticker STGUSDT_SPBL
# Đang theo dõi ticker RUNEUSDT_SPBL
# Đang theo dõi ticker COWUSDT_SPBL
# Đang theo dõi ticker RAYUSDT_SPBL
# Đang theo dõi ticker BSWUSDT_SPBL
# Đang theo dõi ticker DODOUSDT_SPBL
# Đang theo dõi ticker ORCAUSDT_SPBL
# Đang theo dõi ticker MORPHOUSDT_SPBL
# Đang theo dõi ticker BTCUSDE_SPBL
# Đang theo dõi ticker ETHUSDE_SPBL
# Đang theo dõi ticker CHEEMSUSDT_SPBL
# Đang theo dõi ticker ZRCUSDT_SPBL
# Đang theo dõi ticker MEMEFIUSDT_SPBL
# Đang theo dõi ticker AIXBTUSDT_SPBL
# Đang theo dõi ticker CLANKERUSDT_SPBL
# Đang theo dõi ticker CHILLGUYUSDT_SPBL
# Đang theo dõi ticker MAJORNEWUSDT_SPBL
# Đang theo dõi ticker MGTUSDT_SPBL
# Đang theo dõi ticker FUSDT_SPBL
# Đang theo dõi ticker OMUSDT_SPBL
# Đang theo dõi ticker XIONUSDT_SPBL
# Đang theo dõi ticker HBARUSDT_SPBL
# Đang theo dõi ticker ALCHUSDT_SPBL
# Đang theo dõi ticker KOMAUSDT_SPBL
# Đang theo dõi ticker MOZUSDT_SPBL
# Đang theo dõi ticker MEUSDT_SPBL
# Đang theo dõi ticker BGSCUSDT_SPBL
# Đang theo dõi ticker MOVEUSDT_SPBL
# Đang theo dõi ticker ARCUSDT_SPBL
# Đang theo dõi ticker HOLDCOINUSDT_SPBL
# Đang theo dõi ticker GRIFFAINUSDT_SPBL
# Đang theo dõi ticker HYPEUSDT_SPBL
# Đang theo dõi ticker REXUSDT_SPBL
# Đang theo dõi ticker ISLANDUSDT_SPBL
# Đang theo dõi ticker USUALUSDT_SPBL
# Đang theo dõi ticker PENGUUSDT_SPBL
# Đang theo dõi ticker VANAUSDT_SPBL
# Đang theo dõi ticker ALGOUSDT_SPBL
# Đang theo dõi ticker TOMANEWUSDT_SPBL
# Đang theo dõi ticker EARNMUSDT_SPBL
# Đang theo dõi ticker FUELUSDT_SPBL
# Đang theo dõi ticker SONICUSDT_SPBL
# Đang theo dõi ticker BIOUSDT_SPBL
# Đang theo dõi ticker SWARMSUSDT_SPBL
# Đang theo dõi ticker ZEREBROUSDT_SPBL
# Đang theo dõi ticker BLUENEWUSDT_SPBL
# Đang theo dõi ticker WEETHUSDT_SPBL
# Đang theo dõi ticker PHAUSDT_SPBL
# Đang theo dõi ticker AI16ZUSDT_SPBL
# Đang theo dõi ticker GPSUSDT_SPBL
# Đang theo dõi ticker SOLVUSDT_SPBL
# Đang theo dõi ticker TREATUSDT_SPBL
# Đang theo dõi ticker PIPPINUSDT_SPBL
# Đang theo dõi ticker DUSDT_SPBL
# Đang theo dõi ticker BUZZUSDT_SPBL
# Đang theo dõi ticker U2UUSDT_SPBL
# Đang theo dõi ticker XTERUSDT_SPBL
# Đang theo dõi ticker HIVEUSDT_SPBL
# Đang theo dõi ticker SUSDT_SPBL
# Đang theo dõi ticker MELANIAUSDT_SPBL
# Đang theo dõi ticker TRUMPUSDT_SPBL
# Đang theo dõi ticker AVAAIUSDT_SPBL
# Đang theo dõi ticker FARMUSDT_SPBL
# Đang theo dõi ticker NCUSDT_SPBL
# Đang theo dõi ticker VERTUSDT_SPBL
# Đang theo dõi ticker MXNAUSDT_SPBL
# Đang theo dõi ticker DUCKUSDT_SPBL
# Đang theo dõi ticker ONDOUSDC_SPBL
# Đang theo dõi ticker USDSUSDT_SPBL
# Đang theo dõi ticker VINEUSDT_SPBL
# Đang theo dõi ticker ANIMEUSDT_SPBL
# Đang theo dõi ticker SKYUSDT_SPBL
# Đang theo dõi ticker MDOGSUSDT_SPBL
# Đang theo dõi ticker YULIUSDT_SPBL
# Đang theo dõi ticker VTHOUSDT_SPBL
# Đang theo dõi ticker JUSDT_SPBL
# Đang theo dõi ticker PLUMEUSDT_SPBL
# Đang theo dõi ticker TRUMPUSDC_SPBL
# Đang theo dõi ticker ANALOGUSDT_SPBL
# Đang theo dõi ticker JELLYJELLYUSDT_SPBL
# Đang theo dõi ticker INJUSDC_SPBL
# Đang theo dõi ticker PHAUSDC_SPBL
# Đang theo dõi ticker RENDERUSDC_SPBL
# Đang theo dõi ticker PORTALUSDT_SPBL
# Đang theo dõi ticker XLMUSDC_SPBL
# Đang theo dõi ticker ICEUSDT_SPBL
# Đang theo dõi ticker UFDUSDT_SPBL
# Đang theo dõi ticker TAOUSDC_SPBL
# Đang theo dõi ticker FETUSDC_SPBL
# Đang theo dõi ticker MLUSDT_SPBL
# Đang theo dõi ticker PEPEUSDC_SPBL
# Đang theo dõi ticker SUIUSDC_SPBL
# Đang theo dõi ticker MAPOUSDT_SPBL
# Đang theo dõi ticker NESSUSDT_SPBL
# Đang theo dõi ticker SOLBTC_SPBL
# Đang theo dõi ticker AVAXBTC_SPBL
# Đang theo dõi ticker ORDIBTC_SPBL
# Đang theo dõi ticker ALGOUSDC_SPBL
# Đang theo dõi ticker POLUSDC_SPBL
# Đang theo dõi ticker FETBTC_SPBL
# Đang theo dõi ticker USDEUSDC_SPBL
# Đang theo dõi ticker ICPUSDC_SPBL
# Đang theo dõi ticker WENUSDT_SPBL
# Đang theo dõi ticker BERAUSDT_SPBL
# Đang theo dõi ticker KLVUSDT_SPBL
# Đang theo dõi ticker AEVOUSDT_SPBL
# Đang theo dõi ticker FMBUSDT_SPBL
# Đang theo dõi ticker IDUSDT_SPBL
# Đang theo dõi ticker SCAUSDT_SPBL
# Đang theo dõi ticker ARBUSDT_SPBL
# Đang theo dõi ticker TAOUSDT_SPBL
# Đang theo dõi ticker ETHFIUSDT_SPBL
# Đang theo dõi ticker BOMEUSDT_SPBL
# Đang theo dõi ticker BRETTUSDT_SPBL
# Đang theo dõi ticker CGPTUSDT_SPBL
# Đang theo dõi ticker CREOUSDT_SPBL
# Đang theo dõi ticker PENDLEUSDT_SPBL
# Đang theo dõi ticker STETHUSDT_SPBL
# Đang theo dõi ticker AIDOGEUSDT_SPBL
# Đang theo dõi ticker PEPEUSDT_SPBL
# Đang theo dõi ticker ZKUSDT_SPBL
# Đang theo dõi ticker BGBEUR_SPBL
# Đang theo dõi ticker BGBBRL_SPBL
# Đang theo dõi ticker SLERFUSDT_SPBL
# Đang theo dõi ticker TOMIUSDT_SPBL
# Đang theo dõi ticker ALEUSDT_SPBL
# Đang theo dõi ticker MCUSDT_SPBL
# Đang theo dõi ticker MVLUSDT_SPBL
# Đang theo dõi ticker SUIUSDT_SPBL
# Đang theo dõi ticker $DEGENUSDT_SPBL
# Đang theo dõi ticker TURBOUSDT_SPBL
# Đang theo dõi ticker KASUSDT_SPBL
# Đang theo dõi ticker PCIUSDT_SPBL
# Đang theo dõi ticker GFIUSDT_SPBL
# Đang theo dõi ticker ORDIUSDT_SPBL
# Đang theo dõi ticker CATBOYUSDT_SPBL
# Đang theo dõi ticker AEROUSDT_SPBL
# Đang theo dõi ticker LADYSUSDT_SPBL
# Đang theo dõi ticker LYXUSDT_SPBL
# Đang theo dõi ticker USDEUSDT_SPBL
# Đang theo dõi ticker PROPCUSDT_SPBL
# Đang theo dõi ticker OSMOUSDT_SPBL
# Đang theo dõi ticker ZILUSDT_SPBL
# Đang theo dõi ticker MAVUSDT_SPBL
# Đang theo dõi ticker AURORAUSDT_SPBL
# Đang theo dõi ticker NEXOUSDT_SPBL
# Đang theo dõi ticker AMPUSDT_SPBL
# Đang theo dõi ticker LPTUSDT_SPBL
# Đang theo dõi ticker PEPE2USDT_SPBL
# Đang theo dõi ticker PAXGUSDT_SPBL
# Đang theo dõi ticker TELUSDT_SPBL
# Đang theo dõi ticker BGBETH_SPBL
# Đang theo dõi ticker BGBBTC_SPBL
# Đang theo dõi ticker NFTUSDT_SPBL
# Đang theo dõi ticker TUSDUSDT_SPBL
# Đang theo dõi ticker BTTUSDT_SPBL
# Đang theo dõi ticker GLMUSDT_SPBL
# Đang theo dõi ticker NYMUSDT_SPBL
# Đang theo dõi ticker GSTUSDT_SPBL
# Đang theo dõi ticker VTUSDT_SPBL
# Đang theo dõi ticker FLUXUSDT_SPBL
# Đang theo dõi ticker ROSEUSDT_SPBL
# Đang theo dõi ticker NEARUSDT_SPBL
# Đang theo dõi ticker DAIUSDT_SPBL
# Đang theo dõi ticker HNTUSDT_SPBL
# Đang theo dõi ticker WAXPUSDT_SPBL
# Đang theo dõi ticker GALFANUSDT_SPBL
# Đang theo dõi ticker BTCUSDC_SPBL
# Đang theo dõi ticker ENJUSDT_SPBL
# Đang theo dõi ticker MANAUSDT_SPBL
# Đang theo dõi ticker XRPUSDT_SPBL
# Đang theo dõi ticker BTCUSDT_SPBL
# Đang theo dõi ticker ETHUSDT_SPBL
# Đang theo dõi ticker ETHBTC_SPBL
# Đang theo dõi ticker LTCUSDT_SPBL
# Đang theo dõi ticker BCHUSDT_SPBL
# Đang theo dõi ticker ETHUSDC_SPBL
# Đang theo dõi ticker XRPUSDC_SPBL
# Đang theo dõi ticker ADAUSDC_SPBL
# Đang theo dõi ticker SOLUSDC_SPBL
# Đang theo dõi ticker LTCUSDC_SPBL
# Đang theo dõi ticker LINKUSDC_SPBL
# Đang theo dõi ticker DOTUSDC_SPBL
# Đang theo dõi ticker ETCUSDT_SPBL
# Đang theo dõi ticker SHIBUSDT_SPBL
# Đang theo dõi ticker 1INCHUSDT_SPBL
# Đang theo dõi ticker MKRUSDT_SPBL
# Đang theo dõi ticker UMAUSDT_SPBL
# Đang theo dõi ticker ZRXUSDT_SPBL
# Đang theo dõi ticker DOGEUSDC_SPBL
# Đang theo dõi ticker BCHUSDC_SPBL
# Đang theo dõi ticker LUNCUSDT_SPBL
# Đang theo dõi ticker USTCUSDT_SPBL
# Đang theo dõi ticker SXPUSDT_SPBL
# Đang theo dõi ticker OPUSDT_SPBL
# Đang theo dõi ticker BGBUSDC_SPBL
# Đang theo dõi ticker LRCUSDT_SPBL
# Đang theo dõi ticker BALUSDT_SPBL
# Đang theo dõi ticker BNTUSDT_SPBL
# Đang theo dõi ticker CRVUSDT_SPBL
# Đang theo dõi ticker BATUSDT_SPBL
# Đang theo dõi ticker STORJUSDT_SPBL
# Đang theo dõi ticker SNXUSDT_SPBL
# Đang theo dõi ticker DAIUSDC_SPBL
# Đang theo dõi ticker FILUSDC_SPBL
# Đang theo dõi ticker QTUMUSDT_SPBL
# Đang theo dõi ticker LTCBTC_SPBL
# Đang theo dõi ticker XRPBTC_SPBL
# Đang theo dõi ticker OMGUSDT_SPBL
# Đang theo dõi ticker KNCUSDT_SPBL
# Đang theo dõi ticker BANDUSDT_SPBL
# Đang theo dõi ticker GRTUSDT_SPBL
# Đang theo dõi ticker JOEUSDT_SPBL
# Đang theo dõi ticker QUICKUSDT_SPBL
# Đang theo dõi ticker NKNUSDT_SPBL
# Đang theo dõi ticker WBTCUSDT_SPBL
# Đang theo dõi ticker RLCUSDT_SPBL
# Đang theo dõi ticker OGNUSDT_SPBL
# Đang theo dõi ticker CAKEUSDT_SPBL
# Đang theo dõi ticker BNBUSDT_SPBL
# Đang theo dõi ticker CHRUSDT_SPBL
# Đang theo dõi ticker ANKRUSDT_SPBL
# Đang theo dõi ticker RSRUSDT_SPBL
# Đang theo dõi ticker JSTUSDT_SPBL
# Đang theo dõi ticker ICPUSDT_SPBL
# Đang theo dõi ticker ETCBTC_SPBL
# Đang theo dõi ticker LINKBTC_SPBL
# Đang theo dõi ticker TRXBTC_SPBL
# Đang theo dõi ticker AAVEBTC_SPBL
# Đang theo dõi ticker DOGEBTC_SPBL
# Đang theo dõi ticker MASKUSDT_SPBL
# Đang theo dõi ticker TSTBSCUSDT_SPBL
# Đang theo dõi ticker BROCCOLIUSDT_SPBL
# Đang theo dõi ticker PIUSDT_SPBL
# Đang theo dõi ticker SHELLUSDT_SPBL
# Đang theo dõi ticker SOLUSDT_SPBL
# Đang theo dõi ticker IPUSDT_SPBL
# Đang theo dõi ticker HEIUSDT_SPBL
# Đang theo dõi ticker CRVBTC_SPBL
# Đang theo dõi ticker LAYERUSDT_SPBL
# Đang theo dõi ticker JAILSTOOLUSDT_SPBL
# Đang theo dõi ticker ZOOUSDT_SPBL
# Đang theo dõi ticker BGSOLUSDT_SPBL
# Đang theo dõi ticker KAITOUSDT_SPBL
# Đang theo dõi ticker TAPSUSDT_SPBL
# Đang theo dõi ticker REDNEWUSDT_SPBL
# Đang theo dõi ticker ROAMUSDT_SPBL
# Đang theo dõi ticker FILUSDT_SPBL
# Đang theo dõi ticker DEUSDUSDT_SPBL
# Đang theo dõi ticker CELOUSDT_SPBL
# Đang theo dõi ticker ABUSDT_SPBL
# Đang theo dõi ticker BGBUSDT_SPBL
# Đang theo dõi ticker MEMHASHUSDT_SPBL
# Đang theo dõi ticker YGGUSDT_SPBL
# Đang theo dõi ticker LDOUSDT_SPBL
# Đang theo dõi ticker OIKUSDT_SPBL
# Đang theo dõi ticker LVVAUSDT_SPBL
# Đang theo dõi ticker BMTUSDT_SPBL
# Đang theo dõi ticker MINTUSDT_SPBL
# Đang theo dõi ticker ELXUSDT_SPBL
# Đang theo dõi ticker FORMUSDT_SPBL
# Đang theo dõi ticker BRUSDT_SPBL
# Đang theo dõi ticker TUTUSDT_SPBL
# Đang theo dõi ticker PAWSUSDT_SPBL
# Đang theo dõi ticker MUBARAKUSDT_SPBL
# Đang theo dõi ticker BANANAS31USDT_SPBL
# Đang theo dõi ticker IMTUSDT_SPBL
# Đang theo dõi ticker PARTIUSDT_SPBL
# Đang theo dõi ticker NILUSDT_SPBL
# Đang theo dõi ticker BUBBUSDT_SPBL
# Đang theo dõi ticker SIRENUSDT_SPBL
# Đang theo dõi ticker GUNUSDT_SPBL
# Đang theo dõi ticker GHIBLIUSDT_SPBL
# Đang theo dõi ticker KILOUSDT_SPBL
# Đang theo dõi ticker WALUSDT_SPBL
# Đang theo dõi ticker PROMPTUSDT_SPBL
# Đang theo dõi ticker FHEUSDT_SPBL
# Đang theo dõi ticker BABYUSDT_SPBL
# Đang theo dõi ticker RFCUSDT_SPBL
# Đang theo dõi ticker STOUSDT_SPBL
# Đang theo dõi ticker PUMPNEWUSDT_SPBL
# Đang theo dõi ticker BAIUSDT_SPBL
# Đang theo dõi ticker GMNEWUSDT_SPBL
# Đang theo dõi ticker WCTUSDT_SPBL
# Đang theo dõi ticker KERNELUSDT_SPBL
# Đang theo dõi ticker MILKUSDT_SPBL
# Đang theo dõi ticker DEEPUSDT_SPBL
# Đang theo dõi ticker DOLOUSDT_SPBL
# Đang theo dõi ticker INITUSDT_SPBL
# Đang theo dõi ticker ZORAUSDT_SPBL
# Đang theo dõi ticker HYPERUSDT_SPBL
# Đang theo dõi ticker EPTUSDT_SPBL
# Đang theo dõi ticker BANKUSDT_SPBL
# Đang theo dõi ticker DARKUSDT_SPBL
# Đang theo dõi ticker HAEDALUSDT_SPBL
# Đang theo dõi ticker SIGNUSDT_SPBL
# Đang theo dõi ticker LAUNCHCOINUSDT_SPBL
# Đang theo dõi ticker RDACUSDT_SPBL
# Đang theo dõi ticker DOODUSDT_SPBL
# Đang theo dõi ticker SHMUSDT_SPBL
# Đang theo dõi ticker SXTUSDT_SPBL
# Đang theo dõi ticker SYRUPUSDT_SPBL
# Đang theo dõi ticker MYXUSDT_SPBL
# Đang theo dõi ticker OBOLUSDT_SPBL
# Đang theo dõi ticker GORKUSDT_SPBL
# Đang theo dõi ticker HOUSEUSDT_SPBL
# Đang theo dõi ticker MAIUSDT_SPBL
# Đang theo dõi ticker SUIUSD1_SPBL
# Đang theo dõi ticker DOGEUSD1_SPBL
# Đang theo dõi ticker HUMAUSDT_SPBL
# Đang theo dõi ticker USD1USDT_SPBL
# Đang theo dõi ticker USD1USDC_SPBL
# Đang theo dõi ticker SOONNEWUSDT_SPBL
# Đang theo dõi ticker BUSDT_SPBL
# Đang theo dõi ticker AWEUSDT_SPBL
# Đang theo dõi ticker NXPCUSDT_SPBL
# Đang theo dõi ticker PRAIUSDT_SPBL
# Đang theo dõi ticker SKYAIUSDT_SPBL
# Đang theo dõi ticker LABUBUUSDT_SPBL
# Đang theo dõi ticker RLUSDUSDT_SPBL
# Đang theo dõi ticker BUSD1_SPBL
# Đang theo dõi ticker MEWUSDT_SPBL
# Đang theo dõi ticker WUSDT_SPBL
# Đang theo dõi ticker SOPHNEWUSDC_SPBL
# Đang theo dõi ticker IAGUSDT_SPBL
# Đang theo dõi ticker SOPHNEWUSDT_SPBL
# Đang theo dõi ticker AUSDT_SPBL
# Đang theo dõi ticker BTCUSD1_SPBL
# Đang theo dõi ticker ETHUSD1_SPBL
# Đang theo dõi ticker ENAUSDT_SPBL
# Đang theo dõi ticker SOLUSD1_SPBL
# Đang theo dõi ticker XRPUSD1_SPBL
# Đang theo dõi ticker MASAUSDT_SPBL
# Đang theo dõi ticker SAGAUSDT_SPBL
# Đang theo dõi ticker CUDISUSDT_SPBL
# Đang theo dõi ticker TNSRUSDT_SPBL
# Đang theo dõi ticker WNZUSDT_SPBL
# Đang theo dõi ticker LAUSDT_SPBL
# Đang theo dõi ticker MUMUUSDT_SPBL
# Đang theo dõi ticker RWAUSDT_SPBL
# Đang theo dõi ticker BDXNUSDT_SPBL
# Đang theo dõi ticker MOEWUSDT_SPBL
# Đang theo dõi ticker FLOCKUSDT_SPBL
# Đang theo dõi ticker OMNI1USDT_SPBL
# Đang theo dõi ticker PRCLUSDT_SPBL
# Đang theo dõi ticker MASUSDT_SPBL
# Đang theo dõi ticker 0X0USDT_SPBL
# Đang theo dõi ticker SAFEUSDT_SPBL
# Đang theo dõi ticker APUUSDT_SPBL
# Đang theo dõi ticker ALPHUSDT_SPBL
# Đang theo dõi ticker MERLUSDT_SPBL
# Đang theo dõi ticker CKBUSDT_SPBL
# Đang theo dõi ticker AQTUSDT_SPBL
# Đang theo dõi ticker ARKMUSDT_SPBL
# Đang theo dõi ticker BITCOINUSDT_SPBL
# Đang theo dõi ticker UNIBOTUSDT_SPBL
# Đang theo dõi ticker MOGUSDT_SPBL
# Đang theo dõi ticker SIXUSDT_SPBL
# Đang theo dõi ticker MANEKIUSDT_SPBL
# Đang theo dõi ticker KUBUSDT_SPBL
# Đang theo dõi ticker ZBCNUSDT_SPBL
# Đang theo dõi ticker WLDUSDT_SPBL
# Đang theo dõi ticker MXUSDT_SPBL
# Đang theo dõi ticker LNDXUSDT_SPBL
# Đang theo dõi ticker ZEROLENDUSDT_SPBL
# Đang theo dõi ticker KMNOUSDT_SPBL
# Đang theo dõi ticker REZUSDT_SPBL
# Đang theo dõi ticker AZITUSDT_SPBL
# Đang theo dõi ticker SDEXUSDT_SPBL
# Đang theo dõi ticker BBUSDT_SPBL
# Đang theo dõi ticker ZENTUSDT_SPBL
# Đang theo dõi ticker ALUSDT_SPBL
# Đang theo dõi ticker TONCOINUSDC_SPBL
# Đang theo dõi ticker OPUSDC_SPBL
# Đang theo dõi ticker ENAUSDC_SPBL
# Đang theo dõi ticker ARBUSDC_SPBL
# Đang theo dõi ticker BADUSDT_SPBL
# Đang theo dõi ticker SEIUSDT_SPBL
# Đang theo dõi ticker NOTUSDT_SPBL
# Đang theo dõi ticker DRIFTUSDT_SPBL
# Đang theo dõi ticker VIRTUALUSDT_SPBL
# Đang theo dõi ticker GAME2USDT_SPBL
# Đang theo dõi ticker CYBERUSDT_SPBL
# Đang theo dõi ticker FTNUSDT_SPBL
# Đang theo dõi ticker TETUSDT_SPBL
# Đang theo dõi ticker WSDMUSDT_SPBL
# Đang theo dõi ticker XLMUSDT_SPBL
# Đang theo dõi ticker AITECHUSDT_SPBL
# Đang theo dõi ticker GOMININGUSDT_SPBL
# Đang theo dõi ticker VETUSDT_SPBL
# Đang theo dõi ticker NUTSUSDT_SPBL
# Đang theo dõi ticker MAXUSDT_SPBL
# Đang theo dõi ticker BANANAUSDT_SPBL
# Đang theo dõi ticker MCADEUSDT_SPBL
# Đang theo dõi ticker PYUSDUSDT_SPBL
# Đang theo dõi ticker CBKUSDT_SPBL
# Đang theo dõi ticker CRETAUSDT_SPBL
# Đang theo dõi ticker BIGTIMEUSDT_SPBL
# Đang theo dõi ticker STRAXUSDT_SPBL
# Đang theo dõi ticker ORBSUSDT_SPBL
# Đang theo dõi ticker BNBUSDC_SPBL
# Đang theo dõi ticker TRXUSDC_SPBL
# Đang theo dõi ticker XRPEUR_SPBL
# Đang theo dõi ticker SFPUSDT_SPBL
# Đang theo dõi ticker NEARUSDC_SPBL
# Đang theo dõi ticker SOLEUR_SPBL
# Đang theo dõi ticker BSVUSDT_SPBL
# Đang theo dõi ticker AVAXUSDC_SPBL
# Đang theo dõi ticker PPTUSDT_SPBL
# Đang theo dõi ticker UNIUSDC_SPBL
# Đang theo dõi ticker GASUSDT_SPBL
# Đang theo dõi ticker LATUSDT_SPBL
# Đang theo dõi ticker AAVEUSDC_SPBL
# Đang theo dõi ticker SYSUSDT_SPBL
# Đang theo dõi ticker XETAUSDT_SPBL
# Đang theo dõi ticker DAOUSDT_SPBL
# Đang theo dõi ticker CSPRUSDT_SPBL
# Đang theo dõi ticker ZIGUSDT_SPBL
# Đang theo dõi ticker PSGUSDT_SPBL
# Đang theo dõi ticker ACMUSDT_SPBL
# Đang theo dõi ticker BARUSDT_SPBL
# Đang theo dõi ticker PORTOUSDT_SPBL
# Đang theo dõi ticker LAZIOUSDT_SPBL
# Đang theo dõi ticker SANTOSUSDT_SPBL
# Đang theo dõi ticker ASRUSDT_SPBL
# Đang theo dõi ticker ATMUSDT_SPBL
# Đang theo dõi ticker INTERUSDT_SPBL
# Đang theo dõi ticker AFCUSDT_SPBL
# Đang theo dõi ticker SWEATUSDT_SPBL
# Đang theo dõi ticker ETHWUSDT_SPBL
# Đang theo dõi ticker FETUSDT_SPBL
# Đang theo dõi ticker AERGOUSDT_SPBL
# Đang theo dõi ticker AUCTIONUSDT_SPBL
# Đang theo dõi ticker ACHUSDT_SPBL
# Đang theo dõi ticker ALPINEUSDT_SPBL
# Đang theo dõi ticker BADGERUSDT_SPBL
# Đang theo dõi ticker BICOUSDT_SPBL
# Đang theo dõi ticker BAKEUSDT_SPBL
# Đang theo dõi ticker BELUSDT_SPBL
# Đang theo dõi ticker CTSIUSDT_SPBL
# Đang theo dõi ticker CVCUSDT_SPBL
# Đang theo dõi ticker KDAUSDT_SPBL
# Đang theo dõi ticker ELFUSDT_SPBL
# Đang theo dõi ticker FLOWUSDT_SPBL
# Đang theo dõi ticker GHSTUSDT_SPBL
# Đang theo dõi ticker GNOUSDT_SPBL
# Đang theo dõi ticker GTCUSDT_SPBL
# Đang theo dõi ticker GLMRUSDT_SPBL
# Đang theo dõi ticker FLYUSDT_SPBL
# Đang theo dõi ticker RVNUSDT_SPBL
# Đang theo dõi ticker ARUSDC_SPBL
# Đang theo dõi ticker FLOKIUSDC_SPBL
# Đang theo dõi ticker DOGUSDT_SPBL
# Đang theo dõi ticker MINAUSDC_SPBL
# Đang theo dõi ticker SHIBUSDC_SPBL
# Đang theo dõi ticker APTUSDC_SPBL
# Đang theo dõi ticker WUSDUSDT_SPBL
# Đang theo dõi ticker TKOUSDT_SPBL
# Đang theo dõi ticker POLYXUSDT_SPBL
# Đang theo dõi ticker LTCEUR_SPBL
# Đang theo dõi ticker PEPEEUR_SPBL
# Đang theo dõi ticker STXUSDC_SPBL
# Đang theo dõi ticker BEAMUSDT_SPBL
# Đang theo dõi ticker IOUSDT_SPBL
# Đang theo dõi ticker ULTIUSDT_SPBL
# Đang theo dõi ticker GHXUSDT_SPBL
# Đang theo dõi ticker POLUSDT_SPBL
# Đang theo dõi ticker TIAUSDT_SPBL
# Đang theo dõi ticker MEMECOINUSDT_SPBL
# Đang theo dõi ticker MBLUSDT_SPBL
# Đang theo dõi ticker ZKSYNCUSDT_SPBL
# Đang theo dõi ticker COOKIEUSDT_SPBL
# Đang theo dõi ticker PIRATEUSDT_SPBL
# Đang theo dõi ticker T2T2USDT_SPBL
# Đang theo dõi ticker ATHUSDT_SPBL
# Đang theo dõi ticker SATSUSDT_SPBL
# Đang theo dõi ticker HIFIUSDT_SPBL
# Đang theo dõi ticker GROKUSDT_SPBL
# Đang theo dõi ticker BLASTUSDT_SPBL
# Đang theo dõi ticker ZROUSDT_SPBL
# Đang theo dõi ticker LISTAUSDT_SPBL
# Đang theo dõi ticker LNQUSDT_SPBL
# Đang theo dõi ticker NAKAUSDT_SPBL
# Đang theo dõi ticker NPCUSDT_SPBL
# Đang theo dõi ticker NTRNUSDT_SPBL
# Đang theo dõi ticker RATSUSDT_SPBL
# Đang theo dõi ticker DOGEEUR_SPBL
# Đang theo dõi ticker AVAXEUR_SPBL
# Đang theo dõi ticker WELLUSDT_SPBL
# Đang theo dõi ticker QUBICUSDT_SPBL
# Đang theo dõi ticker LINKEUR_SPBL
# Đang theo dõi ticker SWGTUSDT_SPBL
# Đang theo dõi ticker ADAEUR_SPBL
# Đang theo dõi ticker PYTHUSDT_SPBL
# Đang theo dõi ticker ROOTUSDT_SPBL
# Đang theo dõi ticker VRTXUSDT_SPBL
# Đang theo dõi ticker SKLUSDT_SPBL
# Đang theo dõi ticker XTZUSDT_SPBL
# Đang theo dõi ticker NEXAUSDT_SPBL
# Đang theo dõi ticker UXLINKUSDT_SPBL
# Đang theo dõi ticker PIXFIUSDT_SPBL
# Đang theo dõi ticker MOCAUSDT_SPBL
# Đang theo dõi ticker ANYONEUSDT_SPBL
# Đang theo dõi ticker VICUSDT_SPBL
# Đang theo dõi ticker MYROUSDT_SPBL
# Đang theo dõi ticker WOLFUSDT_SPBL
# Đang theo dõi ticker HOLDUSDT_SPBL
# Đang theo dõi ticker FIDAUSDT_SPBL
# Đang theo dõi ticker MYRIAUSDT_SPBL
# Đang theo dõi ticker ACXUSDT_SPBL
# Đang theo dõi ticker AVAILUSDT_SPBL
# Đang theo dõi ticker ZKLUSDT_SPBL
# Đang theo dõi ticker VOXELUSDT_SPBL
# Đang theo dõi ticker GUSDT_SPBL
# Đang theo dõi ticker RIFUSDT_SPBL
# Đang theo dõi ticker CLOUDUSDT_SPBL
# Đang theo dõi ticker ARKUSDT_SPBL
# Đang theo dõi ticker A8USDT_SPBL
# Đang theo dõi ticker LSKUSDT_SPBL
# Đang theo dõi ticker VANRYUSDT_SPBL
# Đang theo dõi ticker GSWIFTUSDT_SPBL
# Đang theo dõi ticker CETUSUSDT_SPBL
# Đang theo dõi ticker JTOUSDT_SPBL
# Đang theo dõi ticker SAMOUSDT_SPBL
# Đang theo dõi ticker CTCUSDT_SPBL
# Đang theo dõi ticker LMWRUSDT_SPBL
# Đang theo dõi ticker ONEUSDT_SPBL
# Đang theo dõi ticker SSVUSDT_SPBL
# Đang theo dõi ticker WAXLUSDT_SPBL
# Đang theo dõi ticker IDEXUSDT_SPBL
# Đang theo dõi ticker INJUSDT_SPBL
# Đang theo dõi ticker IOTXUSDT_SPBL
# Đang theo dõi ticker IQUSDT_SPBL
# Đang theo dõi ticker ALEXUSDT_SPBL
# Đang theo dõi ticker MBXUSDT_SPBL
# Đang theo dõi ticker ACEUSDT_SPBL
# Đang theo dõi ticker ARGUSDT_SPBL
# Đang theo dõi ticker ALUUSDT_SPBL
# Đang theo dõi ticker COQUSDT_SPBL
# Đang theo dõi ticker GMXUSDT_SPBL
# Đang theo dõi ticker LEVERUSDT_SPBL
# Đang theo dõi ticker LOKAUSDT_SPBL
# Đang theo dõi ticker XENUSDT_SPBL
# Đang theo dõi ticker MTLUSDT_SPBL
# Đang theo dõi ticker MINAUSDT_SPBL
# Đang theo dõi ticker NMRUSDT_SPBL
# Đang theo dõi ticker OXTUSDT_SPBL
# Đang theo dõi ticker OGUSDT_SPBL
# Đang theo dõi ticker POWRUSDT_SPBL
# Đang theo dõi ticker PYRUSDT_SPBL
# Đang theo dõi ticker PUNDIXUSDT_SPBL
# Đang theo dõi ticker PONDUSDT_SPBL
# Đang theo dõi ticker PROMUSDT_SPBL
# Đang theo dõi ticker PHBUSDT_SPBL
# Đang theo dõi ticker QKCUSDT_SPBL
# Đang theo dõi ticker QNTUSDT_SPBL
# Đang theo dõi ticker ROUTEUSDT_SPBL
# Đang theo dõi ticker APTUSDT_SPBL
# Đang theo dõi ticker SNTUSDT_SPBL
# Đang theo dõi ticker SUPERUSDT_SPBL
# Đang theo dõi ticker SYNUSDT_SPBL
# Đang theo dõi ticker TUSDT_SPBL
# Đang theo dõi ticker TRBUSDT_SPBL
# Đang theo dõi ticker TWTUSDT_SPBL
# Đang theo dõi ticker WAVESUSDT_SPBL
# Đang theo dõi ticker XCNUSDT_SPBL
# Đang theo dõi ticker XPRUSDT_SPBL
# Đang theo dõi ticker RADUSDT_SPBL
# Đang theo dõi ticker HFTUSDT_SPBL
# Đang theo dõi ticker USDTBRL_SPBL
# Đang theo dõi ticker BTCBRL_SPBL
# Đang theo dõi ticker ETHBRL_SPBL
# Đang theo dõi ticker ONTUSDT_SPBL
# Đang theo dõi ticker ONGUSDT_SPBL
# Đang theo dõi ticker HOOKUSDT_SPBL
# Đang theo dõi ticker AGLDUSDT_SPBL
# Đang theo dõi ticker KAVAUSDT_SPBL
# Đang theo dõi ticker DYDXUSDT_SPBL
# Đang theo dõi ticker OASUSDT_SPBL
# Đang theo dõi ticker CELRUSDT_SPBL
# Đang theo dõi ticker GEARUSDT_SPBL
# Đang theo dõi ticker RACAUSDT_SPBL
# Đang theo dõi ticker BONKUSDT_SPBL
# Đang theo dõi ticker MBOXUSDT_SPBL
# Đang theo dõi ticker AXSUSDT_SPBL
# Đang theo dõi ticker HIGHUSDT_SPBL
# Đang theo dõi ticker GNSUSDT_SPBL
# Đang theo dõi ticker USDTEUR_SPBL
# Đang theo dõi ticker BTCEUR_SPBL
# Đang theo dõi ticker SLPUSDT_SPBL
# Đang theo dõi ticker GALAUSDT_SPBL
# Đang theo dõi ticker ETHEUR_SPBL
# Đang theo dõi ticker SANDUSDT_SPBL
# Đang theo dõi ticker ALICEUSDT_SPBL
# Đang theo dõi ticker TLMUSDT_SPBL
# Đang theo dõi ticker RPLUSDT_SPBL
# Đang theo dõi ticker GODSUSDT_SPBL
# Đang theo dõi ticker DOTUSDT_SPBL
# Đang theo dõi ticker ATOMUSDT_SPBL
# Đang theo dõi ticker IMXUSDT_SPBL
# Đang theo dõi ticker MOVRUSDT_SPBL
# Đang theo dõi ticker ENSUSDT_SPBL
# Đang theo dõi ticker WILDUSDT_SPBL
# Đang theo dõi ticker AVAXUSDT_SPBL
# Đang theo dõi ticker CROUSDT_SPBL
# Đang theo dõi ticker XRPETH_SPBL
# Đang theo dõi ticker ATOMBTC_SPBL
# Đang theo dõi ticker JASMYUSDT_SPBL
# Đang theo dõi ticker TONCOINUSDT_SPBL
# Đang theo dõi ticker CVXUSDT_SPBL
# Đang theo dõi ticker SPELLUSDT_SPBL
# Đang theo dõi ticker HOTUSDT_SPBL
# Đang theo dõi ticker COTIUSDT_SPBL
# Đang theo dõi ticker FXSUSDT_SPBL
# Đang theo dõi ticker CEEKUSDT_SPBL
# Đang theo dõi ticker DENTUSDT_SPBL
# Đang theo dõi ticker FLOKIUSDT_SPBL
# Đang theo dõi ticker FILETH_SPBL
# Đang theo dõi ticker WHYUSDT_SPBL
# Đang theo dõi ticker WIFEUR_SPBL
# Đang theo dõi ticker RENDERUSDT_SPBL
# Đang theo dõi ticker L3USDT_SPBL
# Đang theo dõi ticker MAXNEWUSDT_SPBL
# Đang theo dõi ticker NEIROUSDT_SPBL
# Đang theo dõi ticker DTECUSDT_SPBL
# Đang theo dõi ticker AINUSDT_SPBL
# Đang theo dõi ticker WUFUSDT_SPBL
# Đang theo dõi ticker ICXUSDT_SPBL
# Đang theo dõi ticker NMTUSDT_SPBL
# Đang theo dõi ticker DOGSUSDT_SPBL
# Đang theo dõi ticker SUNDOGUSDT_SPBL
# Đang theo dõi ticker CECUSDT_SPBL
# Đang theo dõi ticker MAKUSDT_SPBL
# Đang theo dõi ticker CPOOLUSDT_SPBL
# Đang theo dõi ticker BRNUSDT_SPBL
# Đang theo dõi ticker SLFUSDT_SPBL
# Đang theo dõi ticker ORDERUSDT_SPBL
# Đang theo dõi ticker EGPUSDT_SPBL
# Đang theo dõi ticker CATIUSDT_SPBL
# Đang theo dõi ticker NEIROCTOUSDT_SPBL
# Đang theo dõi ticker ZCXUSDT_SPBL
# Đang theo dõi ticker HMSTRUSDT_SPBL
# Đang theo dõi ticker PUFFERUSDT_SPBL
# Đang theo dõi ticker CARVUSDT_SPBL
# Đang theo dõi ticker CATSUSDT_SPBL
# Đang theo dõi ticker EIGENUSDT_SPBL
# Đang theo dõi ticker MOODENGUSDT_SPBL
# Đang theo dõi candlestick LUMIAUSDT_SPBL - candle1m
# Đang theo dõi candlestick LUMIAUSDT_SPBL - candle5m
# Đang theo dõi candlestick LUMIAUSDT_SPBL - candle15m
# Đang theo dõi candlestick LUMIAUSDT_SPBL - candle1H
# Đang theo dõi candlestick GOATUSDT_SPBL - candle1m
# Đang theo dõi candlestick GOATUSDT_SPBL - candle5m
# Đang theo dõi candlestick GOATUSDT_SPBL - candle15m
# Đang theo dõi candlestick GOATUSDT_SPBL - candle1H
# Đang theo dõi candlestick ENAEUR_SPBL - candle1m
# Đang theo dõi candlestick ENAEUR_SPBL - candle5m
# Đang theo dõi candlestick ENAEUR_SPBL - candle15m
# Đang theo dõi candlestick ENAEUR_SPBL - candle1H
# Đang theo dõi candlestick TONCOINEUR_SPBL - candle1m
# Đang theo dõi candlestick TONCOINEUR_SPBL - candle5m
# Đang theo dõi candlestick TONCOINEUR_SPBL - candle15m
# Đang theo dõi candlestick TONCOINEUR_SPBL - candle1H
# Đang theo dõi candlestick SXRPSUSDT_SPBL - candle1m
# Đang theo dõi candlestick SXRPSUSDT_SPBL - candle5m
# Đang theo dõi candlestick SXRPSUSDT_SPBL - candle15m
# Đang theo dõi candlestick SXRPSUSDT_SPBL - candle1H
# Đang theo dõi candlestick SHIBEUR_SPBL - candle1m
# Đang theo dõi candlestick SHIBEUR_SPBL - candle5m
# Đang theo dõi candlestick SHIBEUR_SPBL - candle15m
# Đang theo dõi candlestick SHIBEUR_SPBL - candle1H
# Đang theo dõi candlestick WLDEUR_SPBL - candle1m
# Đang theo dõi candlestick WLDEUR_SPBL - candle5m
# Đang theo dõi candlestick WLDEUR_SPBL - candle15m
# Đang theo dõi candlestick WLDEUR_SPBL - candle1H
# Đang theo dõi candlestick DBRUSDT_SPBL - candle1m
# Đang theo dõi candlestick DBRUSDT_SPBL - candle5m
# Đang theo dõi candlestick DBRUSDT_SPBL - candle15m
# Đang theo dõi candlestick DBRUSDT_SPBL - candle1H
# Đang theo dõi candlestick ACTUSDT_SPBL - candle1m
# Đang theo dõi candlestick ACTUSDT_SPBL - candle5m
# Đang theo dõi candlestick ACTUSDT_SPBL - candle15m
# Đang theo dõi candlestick ACTUSDT_SPBL - candle1H
# Đang theo dõi candlestick GRASSUSDT_SPBL - candle1m
# Đang theo dõi candlestick GRASSUSDT_SPBL - candle5m
# Đang theo dõi candlestick GRASSUSDT_SPBL - candle15m
# Đang theo dõi candlestick GRASSUSDT_SPBL - candle1H
# Đang theo dõi candlestick NEIROCTOEUR_SPBL - candle1m
# Đang theo dõi candlestick NEIROCTOEUR_SPBL - candle5m
# Đang theo dõi candlestick NEIROCTOEUR_SPBL - candle15m
# Đang theo dõi candlestick NEIROCTOEUR_SPBL - candle1H
# Đang theo dõi candlestick SUIEUR_SPBL - candle1m
# Đang theo dõi candlestick SUIEUR_SPBL - candle5m
# Đang theo dõi candlestick SUIEUR_SPBL - candle15m
# Đang theo dõi candlestick SUIEUR_SPBL - candle1H
# Đang theo dõi candlestick TRXUSDT_SPBL - candle1m
# Đang theo dõi candlestick TRXUSDT_SPBL - candle5m
# Đang theo dõi candlestick TRXUSDT_SPBL - candle15m
# Đang theo dõi candlestick TRXUSDT_SPBL - candle1H
# Đang theo dõi candlestick XNEWUSDT_SPBL - candle1m
# Đang theo dõi candlestick XNEWUSDT_SPBL - candle5m
# Đang theo dõi candlestick XNEWUSDT_SPBL - candle15m
# Đang theo dõi candlestick XNEWUSDT_SPBL - candle1H
# Đang theo dõi candlestick LINKUSDT_SPBL - candle1m
# Đang theo dõi candlestick LINKUSDT_SPBL - candle5m
# Đang theo dõi candlestick LINKUSDT_SPBL - candle15m
# Đang theo dõi candlestick LINKUSDT_SPBL - candle1H
# Đang theo dõi candlestick ONDOEUR_SPBL - candle1m
# Đang theo dõi candlestick ONDOEUR_SPBL - candle5m
# Đang theo dõi candlestick ONDOEUR_SPBL - candle15m
# Đang theo dõi candlestick ONDOEUR_SPBL - candle1H
# Đang theo dõi candlestick UNIUSDT_SPBL - candle1m
# Đang theo dõi candlestick UNIUSDT_SPBL - candle5m
# Đang theo dõi candlestick UNIUSDT_SPBL - candle15m
# Đang theo dõi candlestick UNIUSDT_SPBL - candle1H
# Đang theo dõi candlestick SUSHIUSDT_SPBL - candle1m
# Đang theo dõi candlestick SUSHIUSDT_SPBL - candle5m
# Đang theo dõi candlestick SUSHIUSDT_SPBL - candle15m
# Đang theo dõi candlestick SUSHIUSDT_SPBL - candle1H
# Đang theo dõi candlestick COMPUSDT_SPBL - candle1m
# Đang theo dõi candlestick COMPUSDT_SPBL - candle5m
# Đang theo dõi candlestick COMPUSDT_SPBL - candle15m
# Đang theo dõi candlestick COMPUSDT_SPBL - candle1H
# Đang theo dõi candlestick SCREUR_SPBL - candle1m
# Đang theo dõi candlestick SCREUR_SPBL - candle5m
# Đang theo dõi candlestick SCREUR_SPBL - candle15m
# Đang theo dõi candlestick SCREUR_SPBL - candle1H
# Đang theo dõi candlestick AAVEUSDT_SPBL - candle1m
# Đang theo dõi candlestick AAVEUSDT_SPBL - candle5m
# Đang theo dõi candlestick AAVEUSDT_SPBL - candle15m
# Đang theo dõi candlestick AAVEUSDT_SPBL - candle1H
# Đang theo dõi candlestick SCRUSDT_SPBL - candle1m
# Đang theo dõi candlestick SCRUSDT_SPBL - candle5m
# Đang theo dõi candlestick SCRUSDT_SPBL - candle15m
# Đang theo dõi candlestick SCRUSDT_SPBL - candle1H
# Đang theo dõi candlestick YFIUSDT_SPBL - candle1m
# Đang theo dõi candlestick YFIUSDT_SPBL - candle5m
# Đang theo dõi candlestick YFIUSDT_SPBL - candle15m
# Đang theo dõi candlestick YFIUSDT_SPBL - candle1H
# Đang theo dõi candlestick NEAREUR_SPBL - candle1m
# Đang theo dõi candlestick NEAREUR_SPBL - candle5m
# Đang theo dõi candlestick NEAREUR_SPBL - candle15m
# Đang theo dõi candlestick NEAREUR_SPBL - candle1H
# Đang theo dõi candlestick DOGEUSDT_SPBL - candle1m
# Đang theo dõi candlestick DOGEUSDT_SPBL - candle5m
# Đang theo dõi candlestick DOGEUSDT_SPBL - candle15m
# Đang theo dõi candlestick DOGEUSDT_SPBL - candle1H
# Đang theo dõi candlestick CHZUSDT_SPBL - candle1m
# Đang theo dõi candlestick CHZUSDT_SPBL - candle5m
# Đang theo dõi candlestick CHZUSDT_SPBL - candle15m
# Đang theo dõi candlestick CHZUSDT_SPBL - candle1H
# Đang theo dõi candlestick PNUTUSDT_SPBL - candle1m
# Đang theo dõi candlestick PNUTUSDT_SPBL - candle5m
# Đang theo dõi candlestick PNUTUSDT_SPBL - candle15m
# Đang theo dõi candlestick PNUTUSDT_SPBL - candle1H
# Đang theo dõi candlestick SWELLUSDT_SPBL - candle1m
# Đang theo dõi candlestick SWELLUSDT_SPBL - candle5m
# Đang theo dõi candlestick SWELLUSDT_SPBL - candle15m
# Đang theo dõi candlestick SWELLUSDT_SPBL - candle1H
# Đang theo dõi candlestick WEETHETH_SPBL - candle1m
# Đang theo dõi candlestick WEETHETH_SPBL - candle5m
# Đang theo dõi candlestick WEETHETH_SPBL - candle15m
# Đang theo dõi candlestick WEETHETH_SPBL - candle1H
# Đang theo dõi candlestick LUCEUSDT_SPBL - candle1m
# Đang theo dõi candlestick LUCEUSDT_SPBL - candle5m
# Đang theo dõi candlestick LUCEUSDT_SPBL - candle15m
# Đang theo dõi candlestick LUCEUSDT_SPBL - candle1H
# Đang theo dõi candlestick FUSEUSDT_SPBL - candle1m
# Đang theo dõi candlestick FUSEUSDT_SPBL - candle5m
# Đang theo dõi candlestick FUSEUSDT_SPBL - candle15m
# Đang theo dõi candlestick FUSEUSDT_SPBL - candle1H
# Đang theo dõi candlestick BANUSDT_SPBL - candle1m
# Đang theo dõi candlestick BANUSDT_SPBL - candle5m
# Đang theo dõi candlestick BANUSDT_SPBL - candle15m
# Đang theo dõi candlestick BANUSDT_SPBL - candle1H
# Đang theo dõi candlestick NFPUSDT_SPBL - candle1m
# Đang theo dõi candlestick NFPUSDT_SPBL - candle5m
# Đang theo dõi candlestick NFPUSDT_SPBL - candle15m
# Đang theo dõi candlestick NFPUSDT_SPBL - candle1H
# Đang theo dõi candlestick NSUSDT_SPBL - candle1m
# Đang theo dõi candlestick NSUSDT_SPBL - candle5m
# Đang theo dõi candlestick NSUSDT_SPBL - candle15m
# Đang theo dõi candlestick NSUSDT_SPBL - candle1H
# Đang theo dõi candlestick HIPPOUSDT_SPBL - candle1m
# Đang theo dõi candlestick HIPPOUSDT_SPBL - candle5m
# Đang theo dõi candlestick HIPPOUSDT_SPBL - candle15m
# Đang theo dõi candlestick HIPPOUSDT_SPBL - candle1H
# Đang theo dõi candlestick PEPECOINUSDT_SPBL - candle1m
# Đang theo dõi candlestick PEPECOINUSDT_SPBL - candle5m
# Đang theo dõi candlestick PEPECOINUSDT_SPBL - candle15m
# Đang theo dõi candlestick PEPECOINUSDT_SPBL - candle1H
# Đang theo dõi candlestick FARTCOINUSDT_SPBL - candle1m
# Đang theo dõi candlestick FARTCOINUSDT_SPBL - candle5m
# Đang theo dõi candlestick FARTCOINUSDT_SPBL - candle15m
# Đang theo dõi candlestick FARTCOINUSDT_SPBL - candle1H
# Đang theo dõi candlestick PEAQUSDT_SPBL - candle1m
# Đang theo dõi candlestick PEAQUSDT_SPBL - candle5m
# Đang theo dõi candlestick PEAQUSDT_SPBL - candle15m
# Đang theo dõi candlestick PEAQUSDT_SPBL - candle1H
# Đang theo dõi candlestick MVUSDT_SPBL - candle1m
# Đang theo dõi candlestick MVUSDT_SPBL - candle5m
# Đang theo dõi candlestick MVUSDT_SPBL - candle15m
# Đang theo dõi candlestick MVUSDT_SPBL - candle1H
# Đang theo dõi candlestick BTCWUSD_SPBL - candle1m
# Đang theo dõi candlestick BTCWUSD_SPBL - candle5m
# Đang theo dõi candlestick BTCWUSD_SPBL - candle15m
# Đang theo dõi candlestick BTCWUSD_SPBL - candle1H
# Đang theo dõi candlestick MOBILEUSDT_SPBL - candle1m
# Đang theo dõi candlestick MOBILEUSDT_SPBL - candle5m
# Đang theo dõi candlestick MOBILEUSDT_SPBL - candle15m
# Đang theo dõi candlestick MOBILEUSDT_SPBL - candle1H
# Đang theo dõi candlestick SWCHUSDT_SPBL - candle1m
# Đang theo dõi candlestick SWCHUSDT_SPBL - candle5m
# Đang theo dõi candlestick SWCHUSDT_SPBL - candle15m
# Đang theo dõi candlestick SWCHUSDT_SPBL - candle1H
# Đang theo dõi candlestick $AIUSDT_SPBL - candle1m
# Đang theo dõi candlestick $AIUSDT_SPBL - candle5m
# Đang theo dõi candlestick $AIUSDT_SPBL - candle15m
# Đang theo dõi candlestick $AIUSDT_SPBL - candle1H
# Đang theo dõi candlestick SOLUSDE_SPBL - candle1m
# Đang theo dõi candlestick SOLUSDE_SPBL - candle5m
# Đang theo dõi candlestick SOLUSDE_SPBL - candle15m
# Đang theo dõi candlestick SOLUSDE_SPBL - candle1H
# Đang theo dõi candlestick SNEKUSDT_SPBL - candle1m
# Đang theo dõi candlestick SNEKUSDT_SPBL - candle5m
# Đang theo dõi candlestick SNEKUSDT_SPBL - candle15m
# Đang theo dõi candlestick SNEKUSDT_SPBL - candle1H
# Đang theo dõi candlestick RIFSOLUSDT_SPBL - candle1m
# Đang theo dõi candlestick RIFSOLUSDT_SPBL - candle5m
# Đang theo dõi candlestick RIFSOLUSDT_SPBL - candle15m
# Đang theo dõi candlestick RIFSOLUSDT_SPBL - candle1H
# Đang theo dõi candlestick OORTUSDT_SPBL - candle1m
# Đang theo dõi candlestick OORTUSDT_SPBL - candle5m
# Đang theo dõi candlestick OORTUSDT_SPBL - candle15m
# Đang theo dõi candlestick OORTUSDT_SPBL - candle1H
# Đang theo dõi candlestick SOLOUSDT_SPBL - candle1m
# Đang theo dõi candlestick SOLOUSDT_SPBL - candle5m
# Đang theo dõi candlestick SOLOUSDT_SPBL - candle15m
# Đang theo dõi candlestick SOLOUSDT_SPBL - candle1H
# Đang theo dõi candlestick XAIUSDT_SPBL - candle1m
# Đang theo dõi candlestick XAIUSDT_SPBL - candle5m
# Đang theo dõi candlestick XAIUSDT_SPBL - candle15m
# Đang theo dõi candlestick XAIUSDT_SPBL - candle1H
# Đang theo dõi candlestick FISUSDT_SPBL - candle1m
# Đang theo dõi candlestick FISUSDT_SPBL - candle5m
# Đang theo dõi candlestick FISUSDT_SPBL - candle15m
# Đang theo dõi candlestick FISUSDT_SPBL - candle1H
# Đang theo dõi candlestick ELAUSDT_SPBL - candle1m
# Đang theo dõi candlestick ELAUSDT_SPBL - candle5m
# Đang theo dõi candlestick ELAUSDT_SPBL - candle15m
# Đang theo dõi candlestick ELAUSDT_SPBL - candle1H
# Đang theo dõi candlestick BONEUSDT_SPBL - candle1m
# Đang theo dõi candlestick BONEUSDT_SPBL - candle5m
# Đang theo dõi candlestick BONEUSDT_SPBL - candle15m
# Đang theo dõi candlestick BONEUSDT_SPBL - candle1H
# Đang theo dõi candlestick RDNTUSDT_SPBL - candle1m
# Đang theo dõi candlestick RDNTUSDT_SPBL - candle5m
# Đang theo dõi candlestick RDNTUSDT_SPBL - candle15m
# Đang theo dõi candlestick RDNTUSDT_SPBL - candle1H
# Đang theo dõi candlestick SAROSUSDT_SPBL - candle1m
# Đang theo dõi candlestick SAROSUSDT_SPBL - candle5m
# Đang theo dõi candlestick SAROSUSDT_SPBL - candle15m
# Đang theo dõi candlestick SAROSUSDT_SPBL - candle1H
# Đang theo dõi candlestick MANTAUSDT_SPBL - candle1m
# Đang theo dõi candlestick MANTAUSDT_SPBL - candle5m
# Đang theo dõi candlestick MANTAUSDT_SPBL - candle15m
# Đang theo dõi candlestick MANTAUSDT_SPBL - candle1H
# Đang theo dõi candlestick PONKEUSDT_SPBL - candle1m
# Đang theo dõi candlestick PONKEUSDT_SPBL - candle5m
# Đang theo dõi candlestick PONKEUSDT_SPBL - candle15m
# Đang theo dõi candlestick PONKEUSDT_SPBL - candle1H
# Đang theo dõi candlestick PROPSUSDT_SPBL - candle1m
# Đang theo dõi candlestick PROPSUSDT_SPBL - candle5m
# Đang theo dõi candlestick PROPSUSDT_SPBL - candle15m
# Đang theo dõi candlestick PROPSUSDT_SPBL - candle1H
# Đang theo dõi candlestick UPCUSDT_SPBL - candle1m
# Đang theo dõi candlestick UPCUSDT_SPBL - candle5m
# Đang theo dõi candlestick UPCUSDT_SPBL - candle15m
# Đang theo dõi candlestick UPCUSDT_SPBL - candle1H
# Đang theo dõi candlestick ORAIUSDT_SPBL - candle1m
# Đang theo dõi candlestick ORAIUSDT_SPBL - candle5m
# Đang theo dõi candlestick ORAIUSDT_SPBL - candle15m
# Đang theo dõi candlestick ORAIUSDT_SPBL - candle1H
# Đang theo dõi candlestick IOSTUSDT_SPBL - candle1m
# Đang theo dõi candlestick IOSTUSDT_SPBL - candle5m
# Đang theo dõi candlestick IOSTUSDT_SPBL - candle15m
# Đang theo dõi candlestick IOSTUSDT_SPBL - candle1H
# Đang theo dõi candlestick COREUSDT_SPBL - candle1m
# Đang theo dõi candlestick COREUSDT_SPBL - candle5m
# Đang theo dõi candlestick COREUSDT_SPBL - candle15m
# Đang theo dõi candlestick COREUSDT_SPBL - candle1H
# Đang theo dõi candlestick $ALTUSDT_SPBL - candle1m
# Đang theo dõi candlestick $ALTUSDT_SPBL - candle5m
# Đang theo dõi candlestick $ALTUSDT_SPBL - candle15m
# Đang theo dõi candlestick $ALTUSDT_SPBL - candle1H
# Đang theo dõi candlestick ONDOUSDT_SPBL - candle1m
# Đang theo dõi candlestick ONDOUSDT_SPBL - candle5m
# Đang theo dõi candlestick ONDOUSDT_SPBL - candle15m
# Đang theo dõi candlestick ONDOUSDT_SPBL - candle1H
# Đang theo dõi candlestick WIFUSDT_SPBL - candle1m
# Đang theo dõi candlestick WIFUSDT_SPBL - candle5m
# Đang theo dõi candlestick WIFUSDT_SPBL - candle15m
# Đang theo dõi candlestick WIFUSDT_SPBL - candle1H
# Đang theo dõi candlestick AVAUSDT_SPBL - candle1m
# Đang theo dõi candlestick AVAUSDT_SPBL - candle5m
# Đang theo dõi candlestick AVAUSDT_SPBL - candle15m
# Đang theo dõi candlestick AVAUSDT_SPBL - candle1H
# Đang theo dõi candlestick THENAUSDT_SPBL - candle1m
# Đang theo dõi candlestick THENAUSDT_SPBL - candle5m
# Đang theo dõi candlestick THENAUSDT_SPBL - candle15m
# Đang theo dõi candlestick THENAUSDT_SPBL - candle1H
# Đang theo dõi candlestick CHESSUSDT_SPBL - candle1m
# Đang theo dõi candlestick CHESSUSDT_SPBL - candle5m
# Đang theo dõi candlestick CHESSUSDT_SPBL - candle15m
# Đang theo dõi candlestick CHESSUSDT_SPBL - candle1H
# Đang theo dõi candlestick ORNJUSDT_SPBL - candle1m
# Đang theo dõi candlestick ORNJUSDT_SPBL - candle5m
# Đang theo dõi candlestick ORNJUSDT_SPBL - candle15m
# Đang theo dõi candlestick ORNJUSDT_SPBL - candle1H
# Đang theo dõi candlestick JUPUSDT_SPBL - candle1m
# Đang theo dõi candlestick JUPUSDT_SPBL - candle5m
# Đang theo dõi candlestick JUPUSDT_SPBL - candle15m
# Đang theo dõi candlestick JUPUSDT_SPBL - candle1H
# Đang theo dõi candlestick DMAILUSDT_SPBL - candle1m
# Đang theo dõi candlestick DMAILUSDT_SPBL - candle5m
# Đang theo dõi candlestick DMAILUSDT_SPBL - candle15m
# Đang theo dõi candlestick DMAILUSDT_SPBL - candle1H
# Đang theo dõi candlestick BLURUSDT_SPBL - candle1m
# Đang theo dõi candlestick BLURUSDT_SPBL - candle5m
# Đang theo dõi candlestick BLURUSDT_SPBL - candle15m
# Đang theo dõi candlestick BLURUSDT_SPBL - candle1H
# Đang theo dõi candlestick API3USDT_SPBL - candle1m
# Đang theo dõi candlestick API3USDT_SPBL - candle5m
# Đang theo dõi candlestick API3USDT_SPBL - candle15m
# Đang theo dõi candlestick API3USDT_SPBL - candle1H
# Đang theo dõi candlestick XAUTUSDT_SPBL - candle1m
# Đang theo dõi candlestick XAUTUSDT_SPBL - candle5m
# Đang theo dõi candlestick XAUTUSDT_SPBL - candle15m
# Đang theo dõi candlestick XAUTUSDT_SPBL - candle1H
# Đang theo dõi candlestick RAREUSDT_SPBL - candle1m
# Đang theo dõi candlestick RAREUSDT_SPBL - candle5m
# Đang theo dõi candlestick RAREUSDT_SPBL - candle15m
# Đang theo dõi candlestick RAREUSDT_SPBL - candle1H
# Đang theo dõi candlestick TRUUSDT_SPBL - candle1m
# Đang theo dõi candlestick TRUUSDT_SPBL - candle5m
# Đang theo dõi candlestick TRUUSDT_SPBL - candle15m
# Đang theo dõi candlestick TRUUSDT_SPBL - candle1H
# Đang theo dõi candlestick BIZAUSDT_SPBL - candle1m
# Đang theo dõi candlestick BIZAUSDT_SPBL - candle5m
# Đang theo dõi candlestick BIZAUSDT_SPBL - candle15m
# Đang theo dõi candlestick BIZAUSDT_SPBL - candle1H
# Đang theo dõi candlestick USDCEUR_SPBL - candle1m
# Đang theo dõi candlestick USDCEUR_SPBL - candle5m
# Đang theo dõi candlestick USDCEUR_SPBL - candle15m
# Đang theo dõi candlestick USDCEUR_SPBL - candle1H
# Đang theo dõi candlestick VRUSDT_SPBL - candle1m
# Đang theo dõi candlestick VRUSDT_SPBL - candle5m
# Đang theo dõi candlestick VRUSDT_SPBL - candle15m
# Đang theo dõi candlestick VRUSDT_SPBL - candle1H
# Đang theo dõi candlestick FIREUSDT_SPBL - candle1m
# Đang theo dõi candlestick FIREUSDT_SPBL - candle5m
# Đang theo dõi candlestick FIREUSDT_SPBL - candle15m
# Đang theo dõi candlestick FIREUSDT_SPBL - candle1H
# Đang theo dõi candlestick CFXUSDT_SPBL - candle1m
# Đang theo dõi candlestick CFXUSDT_SPBL - candle5m
# Đang theo dõi candlestick CFXUSDT_SPBL - candle15m
# Đang theo dõi candlestick CFXUSDT_SPBL - candle1H
# Đang theo dõi candlestick ZETAUSDT_SPBL - candle1m
# Đang theo dõi candlestick ZETAUSDT_SPBL - candle5m
# Đang theo dõi candlestick ZETAUSDT_SPBL - candle15m
# Đang theo dõi candlestick ZETAUSDT_SPBL - candle1H
# Đang theo dõi candlestick MDTUSDT_SPBL - candle1m
# Đang theo dõi candlestick MDTUSDT_SPBL - candle5m
# Đang theo dõi candlestick MDTUSDT_SPBL - candle15m
# Đang theo dõi candlestick MDTUSDT_SPBL - candle1H
# Đang theo dõi candlestick COREUMUSDT_SPBL - candle1m
# Đang theo dõi candlestick COREUMUSDT_SPBL - candle5m
# Đang theo dõi candlestick COREUMUSDT_SPBL - candle15m
# Đang theo dõi candlestick COREUMUSDT_SPBL - candle1H
# Đang theo dõi candlestick VELOUSDT_SPBL - candle1m
# Đang theo dõi candlestick VELOUSDT_SPBL - candle5m
# Đang theo dõi candlestick VELOUSDT_SPBL - candle15m
# Đang theo dõi candlestick VELOUSDT_SPBL - candle1H
# Đang theo dõi candlestick DYMUSDT_SPBL - candle1m
# Đang theo dõi candlestick DYMUSDT_SPBL - candle5m
# Đang theo dõi candlestick DYMUSDT_SPBL - candle15m
# Đang theo dõi candlestick DYMUSDT_SPBL - candle1H
# Đang theo dõi candlestick MAVIAUSDT_SPBL - candle1m
# Đang theo dõi candlestick MAVIAUSDT_SPBL - candle5m
# Đang theo dõi candlestick MAVIAUSDT_SPBL - candle15m
# Đang theo dõi candlestick MAVIAUSDT_SPBL - candle1H
# Đang theo dõi candlestick NAVXUSDT_SPBL - candle1m
# Đang theo dõi candlestick NAVXUSDT_SPBL - candle5m
# Đang theo dõi candlestick NAVXUSDT_SPBL - candle15m
# Đang theo dõi candlestick NAVXUSDT_SPBL - candle1H
# Đang theo dõi candlestick TRACUSDT_SPBL - candle1m
# Đang theo dõi candlestick TRACUSDT_SPBL - candle5m
# Đang theo dõi candlestick TRACUSDT_SPBL - candle15m
# Đang theo dõi candlestick TRACUSDT_SPBL - candle1H
# Đang theo dõi candlestick LQTYUSDT_SPBL - candle1m
# Đang theo dõi candlestick LQTYUSDT_SPBL - candle5m
# Đang theo dõi candlestick LQTYUSDT_SPBL - candle15m
# Đang theo dõi candlestick LQTYUSDT_SPBL - candle1H
# Đang theo dõi candlestick STRKUSDT_SPBL - candle1m
# Đang theo dõi candlestick STRKUSDT_SPBL - candle5m
# Đang theo dõi candlestick STRKUSDT_SPBL - candle15m
# Đang theo dõi candlestick STRKUSDT_SPBL - candle1H
# Đang theo dõi candlestick ASTOUSDT_SPBL - candle1m
# Đang theo dõi candlestick ASTOUSDT_SPBL - candle5m
# Đang theo dõi candlestick ASTOUSDT_SPBL - candle15m
# Đang theo dõi candlestick ASTOUSDT_SPBL - candle1H
# Đang theo dõi candlestick WLDUSDC_SPBL - candle1m
# Đang theo dõi candlestick WLDUSDC_SPBL - candle5m
# Đang theo dõi candlestick WLDUSDC_SPBL - candle15m
# Đang theo dõi candlestick WLDUSDC_SPBL - candle1H
# Đang theo dõi candlestick HTXUSDT_SPBL - candle1m
# Đang theo dõi candlestick HTXUSDT_SPBL - candle5m
# Đang theo dõi candlestick HTXUSDT_SPBL - candle15m
# Đang theo dõi candlestick HTXUSDT_SPBL - candle1H
# Đang theo dõi candlestick NEOUSDT_SPBL - candle1m
# Đang theo dõi candlestick NEOUSDT_SPBL - candle5m
# Đang theo dõi candlestick NEOUSDT_SPBL - candle15m
# Đang theo dõi candlestick NEOUSDT_SPBL - candle1H
# Đang theo dõi candlestick FLMUSDT_SPBL - candle1m
# Đang theo dõi candlestick FLMUSDT_SPBL - candle5m
# Đang theo dõi candlestick FLMUSDT_SPBL - candle15m
# Đang theo dõi candlestick FLMUSDT_SPBL - candle1H
# Đang theo dõi candlestick AZEROUSDT_SPBL - candle1m
# Đang theo dõi candlestick AZEROUSDT_SPBL - candle5m
# Đang theo dõi candlestick AZEROUSDT_SPBL - candle15m
# Đang theo dõi candlestick AZEROUSDT_SPBL - candle1H
# Đang theo dõi candlestick PIXELUSDT_SPBL - candle1m
# Đang theo dõi candlestick PIXELUSDT_SPBL - candle5m
# Đang theo dõi candlestick PIXELUSDT_SPBL - candle15m
# Đang theo dõi candlestick PIXELUSDT_SPBL - candle1H
# Đang theo dõi candlestick PRIME1USDT_SPBL - candle1m
# Đang theo dõi candlestick PRIME1USDT_SPBL - candle5m
# Đang theo dõi candlestick PRIME1USDT_SPBL - candle15m
# Đang theo dõi candlestick PRIME1USDT_SPBL - candle1H
# Đang theo dõi candlestick ELONUSDT_SPBL - candle1m
# Đang theo dõi candlestick ELONUSDT_SPBL - candle5m
# Đang theo dõi candlestick ELONUSDT_SPBL - candle15m
# ...
# Đang theo dõi candlestick BTCBRL_SPBL - candle1m
# Đang theo dõi candlestick BTCBRL_SPBL - candle5m
# Đang theo dõi candlestick BTCBRL_SPBL - candle15m
# Đang theo dõi candlestick BTCBRL_SPBL - candle1H
# Đang theo dõi candlestick ETHBRL_SPBL - candle1m
# Đang theo dõi candlestick ETHBRL_SPBL - candle5m
# Đang theo dõi candlestick ETHBRL_SPBL - candle15m
# Đang theo dõi candlestick ETHBRL_SPBL - candle1H
# Đang theo dõi candlestick ONTUSDT_SPBL - candle1m
# Đang theo dõi candlestick ONTUSDT_SPBL - candle5m
# Đang theo dõi candlestick ONTUSDT_SPBL - candle15m
# Đang theo dõi candlestick ONTUSDT_SPBL - candle1H
# Đang theo dõi candlestick ONGUSDT_SPBL - candle1m
# Đang theo dõi candlestick ONGUSDT_SPBL - candle5m
# Đang theo dõi candlestick ONGUSDT_SPBL - candle15m
# Đang theo dõi candlestick ONGUSDT_SPBL - candle1H
# Đang theo dõi candlestick HOOKUSDT_SPBL - candle1m
# Đang theo dõi candlestick HOOKUSDT_SPBL - candle5m
# Đang theo dõi candlestick HOOKUSDT_SPBL - candle15m
# Đang theo dõi candlestick HOOKUSDT_SPBL - candle1H
# Đang theo dõi candlestick AGLDUSDT_SPBL - candle1m
# Đang theo dõi candlestick AGLDUSDT_SPBL - candle5m
# Đang theo dõi candlestick AGLDUSDT_SPBL - candle15m
# Đang theo dõi candlestick AGLDUSDT_SPBL - candle1H
# Đang theo dõi candlestick KAVAUSDT_SPBL - candle1m
# Đang theo dõi candlestick KAVAUSDT_SPBL - candle5m
# Đang theo dõi candlestick KAVAUSDT_SPBL - candle15m
# Đang theo dõi candlestick KAVAUSDT_SPBL - candle1H
# Đang theo dõi candlestick DYDXUSDT_SPBL - candle1m
# Đang theo dõi candlestick DYDXUSDT_SPBL - candle5m
# Đang theo dõi candlestick DYDXUSDT_SPBL - candle15m
# Đang theo dõi candlestick DYDXUSDT_SPBL - candle1H
# Đang theo dõi candlestick OASUSDT_SPBL - candle1m
# Đang theo dõi candlestick OASUSDT_SPBL - candle5m
# Đang theo dõi candlestick OASUSDT_SPBL - candle15m
# Đang theo dõi candlestick OASUSDT_SPBL - candle1H
# Đang theo dõi candlestick CELRUSDT_SPBL - candle1m
# Đang theo dõi candlestick CELRUSDT_SPBL - candle5m
# Đang theo dõi candlestick CELRUSDT_SPBL - candle15m
# Đang theo dõi candlestick CELRUSDT_SPBL - candle1H
# Đang theo dõi candlestick GEARUSDT_SPBL - candle1m
# Đang theo dõi candlestick GEARUSDT_SPBL - candle5m
# Đang theo dõi candlestick GEARUSDT_SPBL - candle15m
# Đang theo dõi candlestick GEARUSDT_SPBL - candle1H
# Đang theo dõi candlestick RACAUSDT_SPBL - candle1m
# Đang theo dõi candlestick RACAUSDT_SPBL - candle5m
# Đang theo dõi candlestick RACAUSDT_SPBL - candle15m
# Đang theo dõi candlestick RACAUSDT_SPBL - candle1H
# Đang theo dõi candlestick BONKUSDT_SPBL - candle1m
# Đang theo dõi candlestick BONKUSDT_SPBL - candle5m
# Đang theo dõi candlestick BONKUSDT_SPBL - candle15m
# Đang theo dõi candlestick BONKUSDT_SPBL - candle1H
# Đang theo dõi candlestick MBOXUSDT_SPBL - candle1m
# Đang theo dõi candlestick MBOXUSDT_SPBL - candle5m
# Đang theo dõi candlestick MBOXUSDT_SPBL - candle15m
# Đang theo dõi candlestick MBOXUSDT_SPBL - candle1H
# Đang theo dõi candlestick AXSUSDT_SPBL - candle1m
# Đang theo dõi candlestick AXSUSDT_SPBL - candle5m
# Đang theo dõi candlestick AXSUSDT_SPBL - candle15m
# Đang theo dõi candlestick AXSUSDT_SPBL - candle1H
# Đang theo dõi candlestick HIGHUSDT_SPBL - candle1m
# Đang theo dõi candlestick HIGHUSDT_SPBL - candle5m
# Đang theo dõi candlestick HIGHUSDT_SPBL - candle15m
# Đang theo dõi candlestick HIGHUSDT_SPBL - candle1H
# Đang theo dõi candlestick GNSUSDT_SPBL - candle1m
# Đang theo dõi candlestick GNSUSDT_SPBL - candle5m
# Đang theo dõi candlestick GNSUSDT_SPBL - candle15m
# Đang theo dõi candlestick GNSUSDT_SPBL - candle1H
# Đang theo dõi candlestick USDTEUR_SPBL - candle1m
# Đang theo dõi candlestick USDTEUR_SPBL - candle5m
# Đang theo dõi candlestick USDTEUR_SPBL - candle15m
# Đang theo dõi candlestick USDTEUR_SPBL - candle1H
# Đang theo dõi candlestick BTCEUR_SPBL - candle1m
# Đang theo dõi candlestick BTCEUR_SPBL - candle5m
# Đang theo dõi candlestick BTCEUR_SPBL - candle15m
# Đang theo dõi candlestick BTCEUR_SPBL - candle1H
# Đang theo dõi candlestick SLPUSDT_SPBL - candle1m
# Đang theo dõi candlestick SLPUSDT_SPBL - candle5m
# Đang theo dõi candlestick SLPUSDT_SPBL - candle15m
# Đang theo dõi candlestick SLPUSDT_SPBL - candle1H
# Đang theo dõi candlestick GALAUSDT_SPBL - candle1m
# Đang theo dõi candlestick GALAUSDT_SPBL - candle5m
# Đang theo dõi candlestick GALAUSDT_SPBL - candle15m
# Đang theo dõi candlestick GALAUSDT_SPBL - candle1H
# Đang theo dõi candlestick ETHEUR_SPBL - candle1m
# Đang theo dõi candlestick ETHEUR_SPBL - candle5m
# Đang theo dõi candlestick ETHEUR_SPBL - candle15m
# Đang theo dõi candlestick ETHEUR_SPBL - candle1H
# Đang theo dõi candlestick SANDUSDT_SPBL - candle1m
# Đang theo dõi candlestick SANDUSDT_SPBL - candle5m
# Đang theo dõi candlestick SANDUSDT_SPBL - candle15m
# Đang theo dõi candlestick SANDUSDT_SPBL - candle1H
# Đang theo dõi candlestick ALICEUSDT_SPBL - candle1m
# Đang theo dõi candlestick ALICEUSDT_SPBL - candle5m
# Đang theo dõi candlestick ALICEUSDT_SPBL - candle15m
# Đang theo dõi candlestick ALICEUSDT_SPBL - candle1H
# Đang theo dõi candlestick TLMUSDT_SPBL - candle1m
# Đang theo dõi candlestick TLMUSDT_SPBL - candle5m
# Đang theo dõi candlestick TLMUSDT_SPBL - candle15m
# Đang theo dõi candlestick TLMUSDT_SPBL - candle1H
# Đang theo dõi candlestick RPLUSDT_SPBL - candle1m
# Đang theo dõi candlestick RPLUSDT_SPBL - candle5m
# Đang theo dõi candlestick RPLUSDT_SPBL - candle15m
# Đang theo dõi candlestick RPLUSDT_SPBL - candle1H
# Đang theo dõi candlestick GODSUSDT_SPBL - candle1m
# Đang theo dõi candlestick GODSUSDT_SPBL - candle5m
# Đang theo dõi candlestick GODSUSDT_SPBL - candle15m
# Đang theo dõi candlestick GODSUSDT_SPBL - candle1H
# Đang theo dõi candlestick DOTUSDT_SPBL - candle1m
# Đang theo dõi candlestick DOTUSDT_SPBL - candle5m
# Đang theo dõi candlestick DOTUSDT_SPBL - candle15m
# Đang theo dõi candlestick DOTUSDT_SPBL - candle1H
# Đang theo dõi candlestick ATOMUSDT_SPBL - candle1m
# Đang theo dõi candlestick ATOMUSDT_SPBL - candle5m
# Đang theo dõi candlestick ATOMUSDT_SPBL - candle15m
# Đang theo dõi candlestick ATOMUSDT_SPBL - candle1H
# Đang theo dõi candlestick IMXUSDT_SPBL - candle1m
# Đang theo dõi candlestick IMXUSDT_SPBL - candle5m
# Đang theo dõi candlestick IMXUSDT_SPBL - candle15m
# Đang theo dõi candlestick IMXUSDT_SPBL - candle1H
# Đang theo dõi candlestick MOVRUSDT_SPBL - candle1m
# Đang theo dõi candlestick MOVRUSDT_SPBL - candle5m
# Đang theo dõi candlestick MOVRUSDT_SPBL - candle15m
# Đang theo dõi candlestick MOVRUSDT_SPBL - candle1H
# Đang theo dõi candlestick ENSUSDT_SPBL - candle1m
# Đang theo dõi candlestick ENSUSDT_SPBL - candle5m
# Đang theo dõi candlestick ENSUSDT_SPBL - candle15m
# Đang theo dõi candlestick ENSUSDT_SPBL - candle1H
# Đang theo dõi candlestick WILDUSDT_SPBL - candle1m
# Đang theo dõi candlestick WILDUSDT_SPBL - candle5m
# Đang theo dõi candlestick WILDUSDT_SPBL - candle15m
# Đang theo dõi candlestick WILDUSDT_SPBL - candle1H
# Đang theo dõi candlestick AVAXUSDT_SPBL - candle1m
# Đang theo dõi candlestick AVAXUSDT_SPBL - candle5m
# Đang theo dõi candlestick AVAXUSDT_SPBL - candle15m
# Đang theo dõi candlestick AVAXUSDT_SPBL - candle1H
# Đang theo dõi candlestick CROUSDT_SPBL - candle1m
# Đang theo dõi candlestick CROUSDT_SPBL - candle5m
# Đang theo dõi candlestick CROUSDT_SPBL - candle15m
# Đang theo dõi candlestick CROUSDT_SPBL - candle1H
# Đang theo dõi candlestick XRPETH_SPBL - candle1m
# Đang theo dõi candlestick XRPETH_SPBL - candle5m
# Đang theo dõi candlestick XRPETH_SPBL - candle15m
# Đang theo dõi candlestick XRPETH_SPBL - candle1H
# Đang theo dõi candlestick ATOMBTC_SPBL - candle1m
# Đang theo dõi candlestick ATOMBTC_SPBL - candle5m
# Đang theo dõi candlestick ATOMBTC_SPBL - candle15m
# Đang theo dõi candlestick ATOMBTC_SPBL - candle1H
# Đang theo dõi candlestick JASMYUSDT_SPBL - candle1m
# Đang theo dõi candlestick JASMYUSDT_SPBL - candle5m
# Đang theo dõi candlestick JASMYUSDT_SPBL - candle15m
# Đang theo dõi candlestick JASMYUSDT_SPBL - candle1H
# Đang theo dõi candlestick TONCOINUSDT_SPBL - candle1m
# Đang theo dõi candlestick TONCOINUSDT_SPBL - candle5m
# Đang theo dõi candlestick TONCOINUSDT_SPBL - candle15m
# Đang theo dõi candlestick TONCOINUSDT_SPBL - candle1H
# Đang theo dõi candlestick CVXUSDT_SPBL - candle1m
# Đang theo dõi candlestick CVXUSDT_SPBL - candle5m
# Đang theo dõi candlestick CVXUSDT_SPBL - candle15m
# Đang theo dõi candlestick CVXUSDT_SPBL - candle1H
# Đang theo dõi candlestick SPELLUSDT_SPBL - candle1m
# Đang theo dõi candlestick SPELLUSDT_SPBL - candle5m
# Đang theo dõi candlestick SPELLUSDT_SPBL - candle15m
# Đang theo dõi candlestick SPELLUSDT_SPBL - candle1H
# Đang theo dõi candlestick HOTUSDT_SPBL - candle1m
# Đang theo dõi candlestick HOTUSDT_SPBL - candle5m
# Đang theo dõi candlestick HOTUSDT_SPBL - candle15m
# Đang theo dõi candlestick HOTUSDT_SPBL - candle1H
# Đang theo dõi candlestick COTIUSDT_SPBL - candle1m
# Đang theo dõi candlestick COTIUSDT_SPBL - candle5m
# Đang theo dõi candlestick COTIUSDT_SPBL - candle15m
# Đang theo dõi candlestick COTIUSDT_SPBL - candle1H
# Đang theo dõi candlestick FXSUSDT_SPBL - candle1m
# Đang theo dõi candlestick FXSUSDT_SPBL - candle5m
# Đang theo dõi candlestick FXSUSDT_SPBL - candle15m
# Đang theo dõi candlestick FXSUSDT_SPBL - candle1H
# Đang theo dõi candlestick CEEKUSDT_SPBL - candle1m
# Đang theo dõi candlestick CEEKUSDT_SPBL - candle5m
# Đang theo dõi candlestick CEEKUSDT_SPBL - candle15m
# Đang theo dõi candlestick CEEKUSDT_SPBL - candle1H
# Đang theo dõi candlestick DENTUSDT_SPBL - candle1m
# Đang theo dõi candlestick DENTUSDT_SPBL - candle5m
# Đang theo dõi candlestick DENTUSDT_SPBL - candle15m
# Đang theo dõi candlestick DENTUSDT_SPBL - candle1H
# Đang theo dõi candlestick FLOKIUSDT_SPBL - candle1m
# Đang theo dõi candlestick FLOKIUSDT_SPBL - candle5m
# Đang theo dõi candlestick FLOKIUSDT_SPBL - candle15m
# Đang theo dõi candlestick FLOKIUSDT_SPBL - candle1H
# Đang theo dõi candlestick FILETH_SPBL - candle1m
# Đang theo dõi candlestick FILETH_SPBL - candle5m
# Đang theo dõi candlestick FILETH_SPBL - candle15m
# Đang theo dõi candlestick FILETH_SPBL - candle1H
# Đang theo dõi candlestick WHYUSDT_SPBL - candle1m
# Đang theo dõi candlestick WHYUSDT_SPBL - candle5m
# Đang theo dõi candlestick WHYUSDT_SPBL - candle15m
# Đang theo dõi candlestick WHYUSDT_SPBL - candle1H
# Đang theo dõi candlestick WIFEUR_SPBL - candle1m
# Đang theo dõi candlestick WIFEUR_SPBL - candle5m
# Đang theo dõi candlestick WIFEUR_SPBL - candle15m
# Đang theo dõi candlestick WIFEUR_SPBL - candle1H
# Đang theo dõi candlestick RENDERUSDT_SPBL - candle1m
# Đang theo dõi candlestick RENDERUSDT_SPBL - candle5m
# Đang theo dõi candlestick RENDERUSDT_SPBL - candle15m
# Đang theo dõi candlestick RENDERUSDT_SPBL - candle1H
# Đang theo dõi candlestick L3USDT_SPBL - candle1m
# Đang theo dõi candlestick L3USDT_SPBL - candle5m
# Đang theo dõi candlestick L3USDT_SPBL - candle15m
# Đang theo dõi candlestick L3USDT_SPBL - candle1H
# Đang theo dõi candlestick MAXNEWUSDT_SPBL - candle1m
# Đang theo dõi candlestick MAXNEWUSDT_SPBL - candle5m
# Đang theo dõi candlestick MAXNEWUSDT_SPBL - candle15m
# Đang theo dõi candlestick MAXNEWUSDT_SPBL - candle1H
# Đang theo dõi candlestick NEIROUSDT_SPBL - candle1m
# Đang theo dõi candlestick NEIROUSDT_SPBL - candle5m
# Đang theo dõi candlestick NEIROUSDT_SPBL - candle15m
# Đang theo dõi candlestick NEIROUSDT_SPBL - candle1H
# Đang theo dõi candlestick DTECUSDT_SPBL - candle1m
# Đang theo dõi candlestick DTECUSDT_SPBL - candle5m
# Đang theo dõi candlestick DTECUSDT_SPBL - candle15m
# Đang theo dõi candlestick DTECUSDT_SPBL - candle1H
# Đang theo dõi candlestick AINUSDT_SPBL - candle1m
# Đang theo dõi candlestick AINUSDT_SPBL - candle5m
# Đang theo dõi candlestick AINUSDT_SPBL - candle15m
# Đang theo dõi candlestick AINUSDT_SPBL - candle1H
# Đang theo dõi candlestick WUFUSDT_SPBL - candle1m
# Đang theo dõi candlestick WUFUSDT_SPBL - candle5m
# Đang theo dõi candlestick WUFUSDT_SPBL - candle15m
# Đang theo dõi candlestick WUFUSDT_SPBL - candle1H
# Đang theo dõi candlestick ICXUSDT_SPBL - candle1m
# Đang theo dõi candlestick ICXUSDT_SPBL - candle5m
# Đang theo dõi candlestick ICXUSDT_SPBL - candle15m
# Đang theo dõi candlestick ICXUSDT_SPBL - candle1H
# Đang theo dõi candlestick NMTUSDT_SPBL - candle1m
# Đang theo dõi candlestick NMTUSDT_SPBL - candle5m
# Đang theo dõi candlestick NMTUSDT_SPBL - candle15m
# Đang theo dõi candlestick NMTUSDT_SPBL - candle1H
# Đang theo dõi candlestick DOGSUSDT_SPBL - candle1m
# Đang theo dõi candlestick DOGSUSDT_SPBL - candle5m
# Đang theo dõi candlestick DOGSUSDT_SPBL - candle15m
# Đang theo dõi candlestick DOGSUSDT_SPBL - candle1H
# Đang theo dõi candlestick SUNDOGUSDT_SPBL - candle1m
# Đang theo dõi candlestick SUNDOGUSDT_SPBL - candle5m
# Đang theo dõi candlestick SUNDOGUSDT_SPBL - candle15m
# Đang theo dõi candlestick SUNDOGUSDT_SPBL - candle1H
# Đang theo dõi candlestick CECUSDT_SPBL - candle1m
# Đang theo dõi candlestick CECUSDT_SPBL - candle5m
# Đang theo dõi candlestick CECUSDT_SPBL - candle15m
# Đang theo dõi candlestick CECUSDT_SPBL - candle1H
# Đang theo dõi candlestick MAKUSDT_SPBL - candle1m
# Đang theo dõi candlestick MAKUSDT_SPBL - candle5m
# Đang theo dõi candlestick MAKUSDT_SPBL - candle15m
# Đang theo dõi candlestick MAKUSDT_SPBL - candle1H
# Đang theo dõi candlestick CPOOLUSDT_SPBL - candle1m
# Đang theo dõi candlestick CPOOLUSDT_SPBL - candle5m
# Đang theo dõi candlestick CPOOLUSDT_SPBL - candle15m
# Đang theo dõi candlestick CPOOLUSDT_SPBL - candle1H
# Đang theo dõi candlestick BRNUSDT_SPBL - candle1m
# Đang theo dõi candlestick BRNUSDT_SPBL - candle5m
# Đang theo dõi candlestick BRNUSDT_SPBL - candle15m
# Đang theo dõi candlestick BRNUSDT_SPBL - candle1H
# Đang theo dõi candlestick SLFUSDT_SPBL - candle1m
# Đang theo dõi candlestick SLFUSDT_SPBL - candle5m
# Đang theo dõi candlestick SLFUSDT_SPBL - candle15m
# Đang theo dõi candlestick SLFUSDT_SPBL - candle1H
# Đang theo dõi candlestick ORDERUSDT_SPBL - candle1m
# Đang theo dõi candlestick ORDERUSDT_SPBL - candle5m
# Đang theo dõi candlestick ORDERUSDT_SPBL - candle15m
# Đang theo dõi candlestick ORDERUSDT_SPBL - candle1H
# Đang theo dõi candlestick EGPUSDT_SPBL - candle1m
# Đang theo dõi candlestick EGPUSDT_SPBL - candle5m
# Đang theo dõi candlestick EGPUSDT_SPBL - candle15m
# Đang theo dõi candlestick EGPUSDT_SPBL - candle1H
# Đang theo dõi candlestick CATIUSDT_SPBL - candle1m
# Đang theo dõi candlestick CATIUSDT_SPBL - candle5m
# Đang theo dõi candlestick CATIUSDT_SPBL - candle15m
# Đang theo dõi candlestick CATIUSDT_SPBL - candle1H
# Đang theo dõi candlestick NEIROCTOUSDT_SPBL - candle1m
# Đang theo dõi candlestick NEIROCTOUSDT_SPBL - candle5m
# Đang theo dõi candlestick NEIROCTOUSDT_SPBL - candle15m
# Đang theo dõi candlestick NEIROCTOUSDT_SPBL - candle1H
# Đang theo dõi candlestick ZCXUSDT_SPBL - candle1m
# Đang theo dõi candlestick ZCXUSDT_SPBL - candle5m
# Đang theo dõi candlestick ZCXUSDT_SPBL - candle15m
# Đang theo dõi candlestick ZCXUSDT_SPBL - candle1H
# Đang theo dõi candlestick HMSTRUSDT_SPBL - candle1m
# Đang theo dõi candlestick HMSTRUSDT_SPBL - candle5m
# Đang theo dõi candlestick HMSTRUSDT_SPBL - candle15m
# Đang theo dõi candlestick HMSTRUSDT_SPBL - candle1H
# Đang theo dõi candlestick PUFFERUSDT_SPBL - candle1m
# Đang theo dõi candlestick PUFFERUSDT_SPBL - candle5m
# Đang theo dõi candlestick PUFFERUSDT_SPBL - candle15m
# Đang theo dõi candlestick PUFFERUSDT_SPBL - candle1H
# Đang theo dõi candlestick CARVUSDT_SPBL - candle1m
# Đang theo dõi candlestick CARVUSDT_SPBL - candle5m
# Đang theo dõi candlestick CARVUSDT_SPBL - candle15m
# Đang theo dõi candlestick CARVUSDT_SPBL - candle1H
# Đang theo dõi candlestick CATSUSDT_SPBL - candle1m
# Đang theo dõi candlestick CATSUSDT_SPBL - candle5m
# Đang theo dõi candlestick CATSUSDT_SPBL - candle15m
# Đang theo dõi candlestick CATSUSDT_SPBL - candle1H
# Đang theo dõi candlestick EIGENUSDT_SPBL - candle1m
# Đang theo dõi candlestick EIGENUSDT_SPBL - candle5m
# Đang theo dõi candlestick EIGENUSDT_SPBL - candle15m
# Đang theo dõi candlestick EIGENUSDT_SPBL - candle1H
# Đang theo dõi candlestick MOODENGUSDT_SPBL - candle1m
# Đang theo dõi candlestick MOODENGUSDT_SPBL - candle5m
# Đang theo dõi candlestick MOODENGUSDT_SPBL - candle15m
# Đang theo dõi candlestick MOODENGUSDT_SPBL - candle1H
# Hoàn tất subscribe cho 792 coins với 4 timeframes
# Kết nối đã đóng
# Đã ngắt kết nối sau 60 giây.
# Ticker data: 49 messages
# Candlestick data: 0 messages
# Kết nối đã đóng
# Đã ngắt kết nối sau 60 giây.
# Ticker data: 49 messages
# Candlestick data: 0 messages

# %%
# Hiển thị raw data từ ticker messages
print("=== RAW TICKER DATA ===")
print(f"Total ticker messages: {len(all_ticker_data)}")
print("\nFirst 3 ticker messages:")
for i, msg in enumerate(all_ticker_data[:3]):
    print(f"\nMessage {i+1}:")
    print(json.dumps(msg, indent=2))
    
print("\nLast 3 ticker messages:")
for i, msg in enumerate(all_ticker_data[-3:], len(all_ticker_data)-2):
    print(f"\nMessage {i}:")
    print(json.dumps(msg, indent=2))
# Out:
# === RAW TICKER DATA ===
# Total ticker messages: 49
#
# First 3 ticker messages:
#
# Message 1:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "LUMIAUSDT_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:LUMIAUSDT_SPBL doesn't exist",
#   "op": "subscribe"
# }
#
# Message 2:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "GOATUSDT_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:GOATUSDT_SPBL doesn't exist",
#   "op": "subscribe"
# }
#
# Message 3:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "ENAEUR_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:ENAEUR_SPBL doesn't exist",
#   "op": "subscribe"
# }
#
# Last 3 ticker messages:
#
# Message 47:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "OORTUSDT_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:OORTUSDT_SPBL doesn't exist",
#   "op": "subscribe"
# }
#
# Message 48:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "SOLOUSDT_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:SOLOUSDT_SPBL doesn't exist",
#   "op": "subscribe"
# }
#
# Message 49:
# {
#   "event": "error",
#   "arg": {
#     "instType": "SPOT",
#     "channel": "ticker",
#     "instId": "XAIUSDT_SPBL"
#   },
#   "code": 30001,
#   "msg": "instType:SPOT,channel:ticker,instId:XAIUSDT_SPBL doesn't exist",
#   "op": "subscribe"
# }

# %%
# Hiển thị raw data từ candlestick messages
print("=== RAW CANDLESTICK DATA ===")
print(f"Total candlestick messages: {len(all_candlestick_data)}")
print("\nFirst 3 candlestick messages:")
for i, msg in enumerate(all_candlestick_data[:3]):
    print(f"\nMessage {i+1}:")
    print(json.dumps(msg, indent=2))
    
print("\nLast 3 candlestick messages:")
for i, msg in enumerate(all_candlestick_data[-3:], len(all_candlestick_data)-2):
    print(f"\nMessage {i}:")
    print(json.dumps(msg, indent=2))
# Out:
# === RAW CANDLESTICK DATA ===
# Total candlestick messages: 0
#
# First 3 candlestick messages:
#
# Last 3 candlestick messages:

# %%
# Phân tích các loại message trong raw data
print("=== PHÂN TÍCH RAW DATA ===")

# Phân tích ticker messages
ticker_event_types = {}
ticker_action_types = {}

for msg in all_ticker_data:
    # Đếm event types
    event = msg.get('event', 'no_event')
    ticker_event_types[event] = ticker_event_types.get(event, 0) + 1
    
    # Đếm action types
    action = msg.get('action', 'no_action')
    ticker_action_types[action] = ticker_action_types.get(action, 0) + 1

print("TICKER MESSAGE TYPES:")
print(f"Event types: {ticker_event_types}")
print(f"Action types: {ticker_action_types}")

# Phân tích candlestick messages
candle_event_types = {}
candle_action_types = {}
candle_timeframes = {}

for msg in all_candlestick_data:
    # Đếm event types
    event = msg.get('event', 'no_event')
    candle_event_types[event] = candle_event_types.get(event, 0) + 1
    
    # Đếm action types
    action = msg.get('action', 'no_action')
    candle_action_types[action] = candle_action_types.get(action, 0) + 1
    
    # Đếm timeframes
    if 'arg' in msg and 'channel' in msg['arg']:
        timeframe = msg['arg']['channel']
        candle_timeframes[timeframe] = candle_timeframes.get(timeframe, 0) + 1

print("\nCANDLESTICK MESSAGE TYPES:")
print(f"Event types: {candle_event_types}")
print(f"Action types: {candle_action_types}")
print(f"Timeframes: {candle_timeframes}")
# Out:
# === PHÂN TÍCH RAW DATA ===
# TICKER MESSAGE TYPES:
# Event types: {'error': 49}
# Action types: {'no_action': 49}
#
# CANDLESTICK MESSAGE TYPES:
# Event types: {}
# Action types: {}
# Timeframes: {}

# %%
# Lưu raw data vào file JSON để backup
import json

# Lưu ticker raw data
with open('raw_ticker_data.json', 'w', encoding='utf-8') as f:
    json.dump(all_ticker_data, f, indent=2, ensure_ascii=False)

# Lưu candlestick raw data  
with open('raw_candlestick_data.json', 'w', encoding='utf-8') as f:
    json.dump(all_candlestick_data, f, indent=2, ensure_ascii=False)

print("Raw data đã được lưu vào:")
print("- raw_ticker_data.json")
print("- raw_candlestick_data.json")
print(f"Ticker messages: {len(all_ticker_data)}")
print(f"Candlestick messages: {len(all_candlestick_data)}")
# Out:
# Raw data đã được lưu vào:
# - raw_ticker_data.json
# - raw_candlestick_data.json
# Ticker messages: 49
# Candlestick messages: 0

# %%
# Hiển thị sample data structure cho mỗi loại message
print("=== SAMPLE DATA STRUCTURES ===")

# Tìm một ticker message có data
ticker_with_data = None
for msg in all_ticker_data:
    if 'data' in msg and msg['data']:
        ticker_with_data = msg
        break

if ticker_with_data:
    print("TICKER MESSAGE WITH DATA:")
    print(json.dumps(ticker_with_data, indent=2))
    print(f"\nTicker data fields: {list(ticker_with_data['data'][0].keys())}")

# Tìm một candlestick message có data
candle_with_data = None
for msg in all_candlestick_data:
    if 'data' in msg and msg['data']:
        candle_with_data = msg
        break

if candle_with_data:
    print("\n" + "="*50)
    print("CANDLESTICK MESSAGE WITH DATA:")
    print(json.dumps(candle_with_data, indent=2))
    print(f"\nCandlestick data array length: {len(candle_with_data['data'][0])}")
    print("Candlestick data format: [timestamp, open, high, low, close, base_volume, quote_volume, usdt_volume]")
# Out:
# === SAMPLE DATA STRUCTURES ===
